# %%
#import libraries / dependencies
import openpyxl
from openpyxl import load_workbook, Workbook
import csv
from pyexcel.cookbook import merge_all_to_a_book, merge_csv_to_a_book
import os
import re

# %%
#FUNCTIONS BLOCK

#get_filenames: 
#Arguments: raw data filepath (absolute)
#Returns: A tuple of strings representing the files that will be used to 
#represent the data at each step of refinement
def get_filenames(rdfile):
    #EXAMPLE '/Users/default/Downloads/Videology Reports/TruOptik - Monthly Usage - June 2018.xlsx'
    rd = rdfile.split('/')
    path = '/'.join(rd[:-1])
    extractedfile = path+'/Extracted-'+rd[-1][:-4]+'csv'
    correctedfile = path+'/Corrected-'+rd[-1][:-4]+'csv'
    finalfile = path+'/Final-'+rd[-1]
    correctedfile_excel = path+'/Corrected-'+rd[-1]
    return extractedfile, correctedfile, finalfile, correctedfile_excel

get_filenames('/Users/default/Downloads/Videology Reports/TruOptik - Monthly Usage - June 2018.xlsx')

#replacements:
#Argument: the videology category (string)
#Returns: the category with all necessary corrections (string)
#Basically there are duplicates in the categories that are *slightly* different
#and this takes care of those
def replacements(category):
    category = category.replace('Financial','Financial/Insurance Attributes & Behaviors')
    category = category.replace('Financial/Insurance Attributes & Behaviors/Insurance Attributes & Behaviors','Financial/Insurance Attributes & Behaviors')
    category = category.replace('"','')
    category = category.replace('Home & Garden','Home Imp/Décor/Home & Garden/Home&Fam/DIY').replace('Home Imp/Décor/Home Imp/Décor/Home & Garden/Home&Fam/DIY/Home&Fam/DIY','Home Imp/Décor/Home & Garden/Home&Fam/DIY')
    category = category.replace('Demos','Demo')
    category = category.replace('Sports & Outdoors','Sporting & Healthy Living + Sporting Goods/Outdoor')
    category = category.replace('Education/Career','Education & Career')
    category = category.replace('Entertainment/Media','Entertainment & Media')
    category = category.replace('Fashion & Style', 'Fashion/Style; Apparel; Accessories')
    category = category.replace('Health','Health & Fitness/Wellness').replace('Health & Fitness/Wellness & Fitness/Wellness','Health & Fitness/Wellness')
    return category

# %%
#BLOCK 1: EXTRACT THE ATTRIBUTES, IDS, AND USAGE DATA FROM THE EXCEL SHEET and get unique values. Then store in CSV

#absolute filepath to raw_data (Videology Report)
raw_data = '/Users/default/Downloads/Videology Reports/filedump/TruOptik - Monthly Usage - April 2018.xlsx'

#This program will create the edited files in the same location as the original, so look there for the data
extractedfile, correctedfile, finalfile, correctedfile_excel = get_filenames(raw_data)

#use openpyxl library to create a workbook object from the xlsx file so we can work w it
rd_wb = load_workbook(raw_data)

#get the worksheet with the data
#usually the sheet is named 'Behavioral Cost', but sometimes there is a trailing space or its named something else
#because Videology is allergic to consistency. Either way changing the string will get you the desired worksheet
rd_ws = rd_wb['Behavioral Cost']

#the header has the names for each column in the worksheet
header = [x.value for x in list(rd_ws.rows)[0]]
print(header)

#we want the index of the columns for the following: 
#Retargeting Attribute
#Attribute ID (sometimes called External Retargeting ID so just change string)
#Usage (sometimes called Billable Usage)
ra_ind = header.index('Retargeting Attribute')
erid_ind= header.index('Attribute ID')
usage_ind = header.index('Usage')

print([ra_ind, erid_ind, usage_ind])

#The following block of code creates a dictionary of unique attributes
#Dictionary format is "unique_records[attribute] = usage"

unique_records = {}
for item in [[i.value for i in x] for x in rd_ws.iter_rows(min_row=2)]:
    #edit the row if it exists
    if item[ra_ind] is not None: 
        row = [item[ra_ind].replace(',',';').replace('  ',' '),item[erid_ind],item[usage_ind]]
    else:
        pass
    #check for membership in the dictionary keys
    if row[0] in list(unique_records.keys()):
        #if the usage value is an int, add it to the dictionary (this gets rid of excel formulas)
        if isinstance(item[usage_ind],int):
            unique_records[row[0]] += int(item[usage_ind])
    #otherwise create new entry
    elif row[0] not in list(unique_records.keys()):
        unique_records[row[0]] = int(item[usage_ind])

#write this unique record data to a csv
extracted_data = open(extractedfile,'w')
for kv in unique_records.items():
    write = csv.writer(extracted_data)
    write.writerow(kv)
extracted_data.close()
# Out:
# ['Provider', 'Country', 'Retargeting Attribute', 'Attribute ID', 'Device Type', 'Format Type', 'CPU', 'Usage', 'Data Costs', 'Rate Adjustment', 'Adjusted Cost (PC/Mobile)']
# [2, 3, 7]

# %%
#BLOCK 1A: IF THE DATA ISN'T IN A FRIENDLY FORMAT IN THE RAW DATA, INSTEAD USE A SLIGHTLY EDITED VERSION AND CONTINUE FROM THERE

refined_data = '/Users/default/Documents/PythonMisc/Videology Reports - Completed/Edited - Dec2017Categories copy.xlsx'
wb = load_workbook(refined_data)
ws = wb.active
category_dict = {}
for line in [[i.value for i in x] for x in ws.iter_rows()]:
    if line[1].strip() in list(category_dict.keys()):
        category_dict[line[1].strip()] += int(line[2])
    else:
        category_dict[line[1].strip()] = int(line[2])
for key, value in category_dict.items():
    index = list(category_dict.keys()).index(key) + 1
    ws.cell(row = index, column = 4).value = key
    ws.cell(row = index, column = 5).value = value
wb.save(refined_data)

# %%
#BLOCK 2: CATEGORIZE THE UNIQUE VALUES USING PREVIOUS DATA
#load reference file and create a list of lists of its values

db_path = '/Users/default/Documents/PythonMisc/VideologyDatabase.xlsx'
db_file = load_workbook(db_path)
db_ws = db_file.active
db_contents = {}
for attribute, category in [[i.value for i in x] for x in db_ws.iter_rows(max_col=2)]:
    db_contents[attribute] = category
    
print(len(db_contents))
#load file with missing categories and create list of values
edit_file = open(extractedfile,'r')
corrected_vals = []
for line in edit_file:
    attribute = line.replace('"','').strip().split(',',1)[0]
    print(attribute)
    usage = line.replace('"','').strip().split(',',1)[1]
    try:
        if 'hhi' in attribute.lower() or 'income' in attribute.lower():
            corrected_vals.append([attribute,'Income', usage])
        else:
            corrected_vals.append([attribute,db_contents[attribute], usage])
        
    except KeyError:
        corrected_vals.append([attribute,'',usage])
    '''
    TEMPORARY CHANGE
    if attribute in list(ref_data.keys()):
        corrected_vals.append([attribute, db_contents[attribute],usage])
    elif attribute not in list(ref_data.keys()):
        corrected_vals.append([attribute,'',usage])
    '''
corrected_file = open(correctedfile,'w')
for value in corrected_vals:
    write = csv.writer(corrected_file)
    write.writerow(value)
corrected_file.close()
# Out:
# 1410
# Tru Optik > V12Data > Auto Budget > Auto Budget Range <= $29K
# Tru Optik > V12Data > Auto Budget > Auto Budget Range $30k - $49k
# Tru Optik > V12Data > Auto Budget > Auto Budget Range >= $50k
# Tru Optik > V12Data > In Auto Market Predictor > Truck; Van
# Tru Optik > V12Data > In Auto Market Predictor > Luxury; Full Size
# Tru Optik > V12Data > In Auto Market Predictor > Mid Size Car
# Tru Optik > V12Data > In Auto Market Predictor > Small Car
# Tru Optik > V12Data > Baby and Toddlers > Baby Care Accessories ; Baby Food & Bev; Baby Formula; Toddler Diapers
# Tru Optik > V12Data > OTC Medicine/Cough & Cold > OTC - Pain Relievers (Kids; Brand); Cough & Cold (Kids; Brand)
# Tru Optik > V12Data > Income > Income Range: K-$100K-$149.9K
# Tru Optik > V12Data > Financial > Owns Mutual Funds; Stocks; or Bonds
# Tru Optik > V12Data > Financial > Credit Card Holder
# Tru Optik > V12Data > Health & Beauty > Women's Health & Beauty Aids
# Tru Optik > V12Data > Health & Beauty > Men's Health & Beauty Aids
# Tru Optik > Media Source Solutions > Health & Wellness > Exercise
# Tru Optik > V12Data > Pet > Pet Food & Treats
# Tru Optik > Cross Pixel > Financial > Auto/Home/Life Insurance
# Tru Optik > Cross Pixel > Financial > Health Insurance
# Tru Optik > Cross Pixel > Real Estate > Home Buyers
# Tru Optik > Cross Pixel > Travel > US & Canada
# Tru Optik > Cross Pixel > Travel > Caribbean; Central & South America
# Tru Optik > Cross Pixel > Travel > EU; Africa; Asia-Pacific
# Tru Optik > Cross Pixel > Food & Dining > Mid-Scale Restaurants
# Tru Optik > Cross Pixel > Food & Dining > Quick-Serve Restaurants
# Tru Optik > Cross Pixel > Furniture > Furniture Shoppers
# Tru Optik > Cross Pixel > Home & Garden > Home & Garden Shoppers
# Tru Optik > Cross Pixel > Appliances > Major Appliance Shoppers
# Tru Optik > Media Source Solutions > Ethnicity > African American
# Tru Optik > Media Source Solutions > Ethnicity > Hispanic
# Tru Optik > Media Source Solutions > Fashion & Beauty > Women's Apparel & Accessories
# Tru Optik > Media Source Solutions > Fashion & Beauty > Children's Apparel
# Tru Optik > Media Source Solutions > Health & Wellness > Dieting & Weight Loss
# Tru Optik > MillwardBrown > Auto > Auto Enthusiasts
# Tru Optik > MillwardBrown > Auto > Car Intenders
# Tru Optik > MillwardBrown > Business and Financial > Entrepeneurs and Innovators
# Tru Optik > MillwardBrown > Business and Financial > Financial Market Followers
# Tru Optik > MillwardBrown > Business and Financial > Investors
# Tru Optik > MillwardBrown > Business and Financial > Online Bankers
# Tru Optik > MillwardBrown > Communities and Lifestyle > Decoristas
# Tru Optik > MillwardBrown > Communities and Lifestyle > Fashionistas
# Tru Optik > MillwardBrown > Communities and Lifestyle > Fine Diners
# Tru Optik > MillwardBrown > Communities and Lifestyle > Generation Social First
# Tru Optik > MillwardBrown > Communities and Lifestyle > Gourmets and Gourmands
# Tru Optik > MillwardBrown > Communities and Lifestyle > Naturalist
# Tru Optik > MillwardBrown > Communities and Lifestyle > New and Expecting Moms
# Tru Optik > MillwardBrown > Entertainment > Audiophiles
# Tru Optik > MillwardBrown > Entertainment > Celeb Watchers
# Tru Optik > MillwardBrown > Entertainment > Concert Goers
# Tru Optik > MillwardBrown > Entertainment > Gamers
# Tru Optik > MillwardBrown > Entertainment > On-Demand Video Watchers
# Tru Optik > MillwardBrown > Entertainment > Online Readers
# Tru Optik > MillwardBrown > Entertainment > Traditional TV Watchers
# Tru Optik > MillwardBrown > Entertainment > Urban Intelligensia
# Tru Optik > MillwardBrown > Entertainment > Video Explorers
# Tru Optik > MillwardBrown > Health & Fitness > Health Nuts
# Tru Optik > MillwardBrown > Health & Fitness > Patients; Caregivers; and Health Professionals
# Tru Optik > MillwardBrown > Health & Fitness > Symptoms and Diagnosis
# Tru Optik > MillwardBrown > News and Info > Affluent Intellects
# Tru Optik > Alliant > Auto > Auto - In Market New Vehicle
# Tru Optik > MillwardBrown > News and Info > Hipsters
# Tru Optik > MillwardBrown > News and Info > Opinion Elites
# Tru Optik > MillwardBrown > News and Info > Search and Click
# Tru Optik > MillwardBrown > News and Info > Tech Elite
# Tru Optik > MillwardBrown > News and Info > The Inside of the Beltway Crowd
# Tru Optik > MillwardBrown > News and Info > Weather Watchers
# Tru Optik > MillwardBrown > Sports > Football Fans
# Tru Optik > MillwardBrown > Sports > Live Sports Watchers
# Tru Optik > MillwardBrown > Sports > Sports Fans
# Tru Optik > MillwardBrown > Travel > Globe Trotters
# Tru Optik > MillwardBrown > Travel > Travel Seekers
# Tru Optik > Alliant > Purchase Affinity > Cooking/Food Enthusiasts
# Tru Optik > Alliant > Auto > Auto - In Market for Used Vehicle
# Tru Optik > Alliant > Purchase Affinity > Health Wellness and Fitness
# Tru Optik > Alliant > Purchase Affinity > Home Decor
# Tru Optik > Alliant > Purchase Affinity > Sports Enthusiasts
# Tru Optik > Alliant > Movers > New Movers
# Tru Optik > Alliant > Purchase Affinity > Moms Who Shop Like Crazy
# Tru Optik > Alliant > Purchase Affinity > Affluent Consumers
# Tru Optik > Alliant > Purchase Affinity > Fitness and Exercise
# Tru Optik > Alliant > Purchase Affinity > Weight Loss
# Tru Optik > Alliant > Auto > Auto - In Market for Parts & Service
# Tru Optik > Alliant > Demographics > Household Income 50k+
# Tru Optik > Alliant > Demographics > Household Income 100k+
# Tru Optik > Alliant > Demographics > Household Income 150k+
# Tru Optik > Alliant > Demographics > Household Presence of Children Age 0-4
# Tru Optik > Alliant > Demographics > Household Presence of Children Age 4-8
# Tru Optik > Alliant > Demographics > Household Presence of Children Age 8-13
# Tru Optik > Alliant > Demographics > Household Presence of Children Age 13-18
# Tru Optik > Alliant > Propensity > Cruise Travel - Propensity
# Tru Optik > Alliant > Propensity > Online Travel Planners - Propensity
# Tru Optik > Alliant > Propensity > Dog Product Buyer - Propensity
# Tru Optik > Alliant > Propensity > NASCAR Fans - Propensity
# Tru Optik > Alliant > Home Renovation > Home Renovators
# Tru Optik > Alliant > Demographics > 18-25
# Tru Optik > Netwise > Professionals > Teachers & Educators
# Tru Optik > Netwise > Professionals > Healthcare Professionals
# Tru Optik > Netwise > Demographics > Age 30 - 49
# Tru Optik > Netwise > Demographics > Age 50+
# Tru Optik > NinthDecimal > Do It Yourself DIY > Home Improvement/Hardware Shoppers
# Tru Optik > NinthDecimal > Food & Dining > Casual Dining
# Tru Optik > NinthDecimal > Food & Dining > Fast Food Enthusiasts
# Tru Optik > NinthDecimal > Sports and Healthy Living > Outdoor Enthusiasts
# Tru Optik > NinthDecimal > Sports and Healthy Living > Health & Fitness Enthusiasts
# Tru Optik > NinthDecimal > Technology > Tech Enthusiasts
# Tru Optik > NinthDecimal > Auto > In Market Auto Intenders
# Tru Optik > NinthDecimal > Lifestyle > College Students
# Tru Optik > NinthDecimal > Retail > Jewelry Store Shoppers
# Tru Optik > NinthDecimal > Retail > Grocery Store Shoppers
# Tru Optik > Dataline > Demographics > Age 50-54
# Tru Optik > Dataline > Demographics > Age 18-24
# Tru Optik > Dataline > Demographics > Age 25-34
# Tru Optik > Dataline > Demographics > Age 35-49
# Tru Optik > Dataline > Demographics > Age 35-44
# Tru Optik > Dataline > Demographics > Age 45-49
# Tru Optik > Dataline > Demographics > Age 50-59
# Tru Optik > Dataline > Demographics > Age 60-99
# Tru Optik > Dataline > Demographics > Age 40-49
# Tru Optik > Dataline > Demographics > Age 22-29
# Tru Optik > Dataline > Enthusiasts > Sports Enthusiast
# Tru Optik > Dataline > Enthusiasts > Travel Enthusiast
# Tru Optik > Dataline > Enthusiasts > Gardening Enthusiast
# Tru Optik > Dataline > Income > Income $25;000-$29;999
# Tru Optik > Dataline > Income > Income $30;000-$34;999
# Tru Optik > Dataline > Income > Income $35;000-$39;999
# Tru Optik > Dataline > Income > Income Less than $15;000
# Tru Optik > Dataline > Income > Income $15;000-$19;999
# Tru Optik > Dataline > Income > Income $20;000-$24;999
# Tru Optik > Dataline > Income > Income $75;000-$79;999
# Tru Optik > Dataline > Income > Income $80;000-$84;999
# Tru Optik > Dataline > Income > Income $50;000-$54;999
# Tru Optik > Dataline > Income > Income $60;000-$64;999
# Tru Optik > Dataline > Income > Income $150;000-$199;999
# Tru Optik > Dataline > Income > Income $125;000-$149;999
# Tru Optik > Dataline > Income > Income $250;000-$299;999
# Tru Optik > Dataline > Income > Income $200;000-$249;999
# Tru Optik > Dataline > Income > Income $90;000-$94;999
# Tru Optik > Dataline > Income > Income $85;000-$89;999
# Tru Optik > Dataline > Income > Income $100;000-$124;999
# Tru Optik > Dataline > Income > Income $95;000-$99;999
# Tru Optik > Dataline > Income > Income $355;000-$399;999
# Tru Optik > Dataline > Income > Income $300;000-$349;999
# Tru Optik > Dataline > Income > Income $400;000-$449;999
# Tru Optik > Dataline > Income > Income $500;000 and above
# Tru Optik > Dataline > Income > Income $450;000-$499;999
# Tru Optik > Dataline > Buyers > Outdoor Grill/Outdoor Furniture Buyer
# Tru Optik > Dataline > Buyers > Premium Credit Card
# Tru Optik > Dataline > Buyers > Children's Apparel Buyer
# Tru Optik > Dataline > Buyers > Teen's Apparel Buyer
# Tru Optik > Dataline > Buyers > Women's Apparel Buyer
# Tru Optik > Dataline > Buyers > Furniture Buyer
# Tru Optik > Dataline > Buyers > Home Care Buyer
# Tru Optik > Dataline > Buyers > Gardening Products Buyer
# Tru Optik > Dataline > Buyers > Jewelry Buyer
# Tru Optik > Dataline > Buyers > Pet Products Buyer
# Tru Optik > Dataline > Enthusiasts > Collectible Enthusiast
# Tru Optik > Dataline > Enthusiasts > Hunting & Fishing Enthusiast
# Tru Optik > Dataline > Enthusiasts > Golf Enthusiast
# Tru Optik > Dataline > Enthusiasts > Wellness Enthusiast
# Tru Optik > Dataline > Purchasing Interest > Heart Health Purchasing Interest
# Tru Optik > Dataline > Purchasing Interest > Natural Health Products Purchasing Interest
# Tru Optik > NinthDecimal > Food & Dining > QSR/Fast Food
# Tru Optik > NinthDecimal > Auto > In-Market Auto Intenders - Luxury
# Tru Optik > NinthDecimal > Auto > In-Market Auto Intenders - Mid-Market
# Tru Optik > NinthDecimal > Auto > In-Market Auto Intenders - Youth/Economy
# Tru Optik > NinthDecimal > Shopper > Furniture Store Shoppers
# Tru Optik > NinthDecimal > Travel > Car Renters
# Tru Optik > NinthDecimal > Travel > Hotel Customers
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > Premium Retail/Gas Card Holders
# Tru Optik > Webbula > Demographics > Family Composition > Children in Household > Age of Children > 16-17 years
# Tru Optik > Webbula > Demographics > Family Composition > Children in Household > Age of Children > 11-15 years
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > American Express Gold Premium
# Tru Optik > Webbula > Demographics > Family Composition > Children in Household > Age of Children > 6-10 years
# Tru Optik > Webbula > Demographics > Family Composition > Children in Household > Age of Children > 0-2 years
# Tru Optik > Webbula > Demographics > Family Composition > Children in Household > Age of Children > 3-5 years
# Tru Optik > Webbula > Demographics > Family Composition > Adult in Household > Age of Adult > 18-24 years
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > Travel/Entertainment Card
# Tru Optik > Webbula > Demographics > Family Composition > Children in Household > Number of Children > 4 +
# Tru Optik > Webbula > Demographics > Family Composition > Children in Household > Number of Children > 0
# Tru Optik > Webbula > Demographics > Family Composition > Children in Household > Number of Children > 1
# Tru Optik > Webbula > Demographics > Family Composition > Children in Household > Number of Children > 2
# Tru Optik > Webbula > Demographics > Family Composition > Children in Household > Number of Children > 3
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > Premium MasterCard
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > American Express
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > Premium Discover
# Tru Optik > Webbula > Demographics > Financial Attributes > New Credit Line Amount > $501 - $1;000
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > Retail/Gas Card
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $100;000 - $124;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $125;000 - $149;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $150;000 - $174;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $175;000 - $199;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $200;000 - $224;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $225;000 - $249;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $250;000 - $274;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $275;000 - $299;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $300;000 - $349;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $350;000 - $399;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $400;000 - $449;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $450;000 - $499;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $500;000 - $749;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $750;000 - $999;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Ownership > Owner > Highly Likely
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $25;000 - $49;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $50;000 - $74;999
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $75;000 - $99;999
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Dealer/Retailer/Storekeeper
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > Premium Visa
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $1;000 - $24;999
# Tru Optik > Webbula > Demographics > Financial Attributes > New Credit Line Amount > $1;001 +
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > MasterCard
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Ownership > Owner > Probable
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Ownership > Owner > Verified
# Tru Optik > Webbula > Demographics > Employment > Occupation > Administration / Managerial
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > Discover
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Distributor/Wholesaler
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > Premium
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $1;000;000+
# Tru Optik > Webbula > Demographics > Financial Attributes > Active Lines of Credit > 4 +
# Tru Optik > Webbula > Demographics > Financial Attributes > Income > $100;000 - $149;999
# Tru Optik > Webbula > Demographics > Financial Attributes > Income > $200;000 - $249;999
# Tru Optik > Webbula > Demographics > Financial Attributes > New Credit Card Issued > Yes
# Tru Optik > Webbula > Demographics > Employment > Occupation > Professional / Technical
# Tru Optik > Webbula > Demographics > Employment > Occupation > Clerical / White Collar
# Tru Optik > Webbula > Demographics > Employment > Occupation > Craftsman / Blue Collar
# Tru Optik > Webbula > Demographics > Financial Attributes > Active Lines of Credit > 1
# Tru Optik > Webbula > Demographics > Financial Attributes > Active Lines of Credit > 2
# Tru Optik > Webbula > Demographics > Financial Attributes > Active Lines of Credit > 3
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > Visa
# Tru Optik > Webbula > Demographics > Financial Attributes > Income > $75;000 - $99;999
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Maker/Manufacturer
# Tru Optik > Webbula > Demographics > Family Composition > Children in Household > Yes
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Dominican Republic
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Funeral Director
# Tru Optik > Webbula > Demographics > Employment > African American Professionals
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Ownership > Owner
# Tru Optik > Webbula > Demographics > Family Composition > Roles > Single Parent
# Tru Optik > Webbula > Demographics > Financial Attributes > Income > $200;000 +
# Tru Optik > Webbula > Demographics > Financial Attributes > Loans > Auto Loans
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Accountant
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Contractor
# Tru Optik > Webbula > Demographics > Financial Attributes > Loans > Refinance
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > El Salvador
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Puerto Rico
# Tru Optik > Webbula > Demographics > Education > Vocational/Technical School
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Costa Rica
# Tru Optik > Webbula > Demographics > Ethnicity > Caribbean African American
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Argentina
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Guatemala
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Venezuela
# Tru Optik > Webbula > Demographics > Military Status > Veteran in Household
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Builder
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Partner
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Colombia
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Honduras
# Tru Optik > Webbula > Demographics > Ethnicity > Central African Republic
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Bolivia
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Ecuador
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Owner
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Brazil
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Mexico
# Tru Optik > Webbula > Demographics > Employment > Occupation > Military
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Spain
# Tru Optik > Webbula > Demographics > Employment > Status > Job Seekers
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Cuba
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Peru
# Tru Optik > Webbula > Demographics > Education > Undergraduate Degree
# Tru Optik > Webbula > Demographics > Education > High School Diploma
# Tru Optik > Webbula > Demographics > Employment > Status > Student
# Tru Optik > Webbula > Demographics > Ethnicity > African American
# Tru Optik > Webbula > Demographics > Education > Graduate Degree
# Tru Optik > Webbula > Demographics > Ethnicity > South African
# Tru Optik > Webbula > Demographics > Ethnic Group > Hispanic
# Tru Optik > Webbula > Demographics > Ethnicity > Hispanic
# Tru Optik > Webbula > Demographics > Gender > Female
# Tru Optik > Webbula > Demographics > Age > 18-24
# Tru Optik > Webbula > Demographics > Financial Attributes > Mortgage Holder > Loan to Value > 1 - 100 LTV
# Tru Optik > Webbula > Demographics > Financial Attributes > Mortgage Holder > Prospector Home Value > $50;000 - $74;999
# Tru Optik > Webbula > Demographics > Financial Attributes > Mortgage Holder > Prospector Home Value > $75;000 - $99;999
# Tru Optik > Webbula > Demographics > Financial Attributes > Mortgage Holder > Purchase Price > $150;000 - $199;999
# Tru Optik > Webbula > Demographics > Tobacco Consumption > Yes
# Tru Optik > Webbula > Historical Buyer or Shopper of > Apparel > Infant & Toddler Clothes
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Auto Leaser
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Auto Owner
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Classes > Convertibles
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Classes > Coupes
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Classes > Economy Cars
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Classes > Hatchback
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Classes > Luxury
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Classes > Sedan
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Classes > Sports Car
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Fuel Type > Diesel
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Fuel Type > Gasoline
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Fuel Type > Hybrid; Electric; and Flexible Fuels
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Lien > No
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Lien > Yes
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Acura
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > American Motors
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Aston-Martin
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Audi
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Bentley
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > BMW
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Buick
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Cadillac
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Chevrolet
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Chrysler
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Dodge
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Ford
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > General Motors
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Geo
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > High End Imports
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Honda
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Hummer
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Hyundai
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Infiniti
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Isuzu
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Jaguar
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Jeep
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Kia
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Land-Rover
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Lexus
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Lincoln
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Low End Imports
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Mazda
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Mercedes Benz
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Mercury
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Mini
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Mitsubishi
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Nissan
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Oldsmobile
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Peugeot
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Plymouth
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Pontiac
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > RAM
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Saab
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Saturn
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Scion
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Subaru
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Suzuki
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Toyota
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Volkswagen
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Volvo
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Number of Vehicles > 1
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Number of Vehicles > 2
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Number of Vehicles > 3
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Number of Vehicles > 4 +
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Purchase Type > New
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Purchase Type > Used
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > transaction > Change of Ownership
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > transaction > New Registration
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > transaction > Other
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1989 or earlier
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1990
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1991
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1995
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1996
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1997
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1998
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1999
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2000
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2001
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2002
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2003
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2004
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2005
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2006
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2007
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2008
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2009
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2010
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2011
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2012
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2013
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2014
# Tru Optik > Webbula > Historical Buyer or Shopper of > Charitable Donations > Arts & Culture
# Tru Optik > Webbula > Historical Buyer or Shopper of > Charitable Donations > Politically Liberal
# Tru Optik > Webbula > Historical Buyer or Shopper of > Health & Beauty Products > Dental & Oral
# Tru Optik > Webbula > Historical Buyer or Shopper of > Health & Beauty Products > Medical
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Apparel > Jewelry
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Apparel > Women's
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Children's Products > Back to School
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Entertainment
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Entertainment > Board Games & Puzzles
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Entertainment > Computer & Video Games
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Entertainment > Computer Games
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Entertainment > DVDs
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Entertainment > Video Games
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Home & Garden
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Home & Garden > Appliances
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Home & Garden > Furnishings & Decor
# Tru Optik > Webbula > Historical Buyer or Shopper of > Retail > Home & Garden > Gardening
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Art
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Cable TV
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Casions & Gambling
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Celebrities
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Games
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Performing Arts
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Photography
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Books
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Business
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Children's Interests
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Current Affairs & Politics
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Inspirational
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Magazines
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Military History
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Parenting
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Science Fiction
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Satellite TV
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Sweepstakes & Contests
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > The Arts
# Tru Optik > Webbula > Passionate About > Business & Finance > Investing
# Tru Optik > Webbula > Passionate About > Business & Finance > Investing > Active Investing
# Tru Optik > Webbula > Passionate About > Business & Finance > Investing > Financial Services
# Tru Optik > Webbula > Passionate About > Business & Finance > Investing > Personal Finance
# Tru Optik > Webbula > Passionate About > Business & Finance > Investing > Real Estate
# Tru Optik > Webbula > Passionate About > Business & Finance > Investing > Stocks
# Tru Optik > Webbula > Passionate About > Education > Career
# Tru Optik > Webbula > Passionate About > Education > Career Improvement
# Tru Optik > Webbula > Passionate About > Education > Extended & Continuing Education
# Tru Optik > Webbula > Passionate About > Education > Online
# Tru Optik > Webbula > Passionate About > Food & Drink > Gourmet
# Tru Optik > Webbula > Passionate About > Health & Beauty
# Tru Optik > Webbula > Passionate About > Health & Beauty > Fitness
# Tru Optik > Webbula > Passionate About > Health & Beauty > Fitness > Aerobics
# Tru Optik > Webbula > Passionate About > Health & Beauty > Fitness > Running
# Tru Optik > Webbula > Passionate About > Health & Beauty > Fitness > Walking
# Tru Optik > Webbula > Passionate About > Health & Beauty > Weight Loss
# Tru Optik > Webbula > Passionate About > Hobbies > Collecting > Military Memorabilia
# Tru Optik > Webbula > Passionate About > Home & Garden > Home Improvement
# Tru Optik > Webbula > Passionate About > Internet & Online Activities > Email Buyer
# Tru Optik > Webbula > Passionate About > Internet & Online Activities > Email Responder
# Tru Optik > Webbula > Passionate About > Internet & Online Activities > News
# Tru Optik > Webbula > Passionate About > Internet & Online Activities > Shopper and Purchaser
# Tru Optik > Webbula > Passionate About > Pets > Cats
# Tru Optik > Webbula > Passionate About > Internet & Online Activities > Social Networking > Active Facebook User
# Tru Optik > Webbula > Passionate About > Outdoor Activities
# Tru Optik > Webbula > Passionate About > Outdoor Activities > Camping
# Tru Optik > Webbula > Passionate About > Outdoor Activities > Equestrian
# Tru Optik > Webbula > Passionate About > Outdoor Activities > Fishing
# Tru Optik > Webbula > Passionate About > Outdoor Activities > Golf
# Tru Optik > Webbula > Passionate About > Outdoor Activities > Hunting & Shooting
# Tru Optik > Webbula > Passionate About > Outdoor Activities > Skiing & Snowboarding
# Tru Optik > Webbula > Passionate About > Pets
# Tru Optik > Webbula > Passionate About > Pets > Dogs
# Tru Optik > Webbula > Passionate About > Pets > Other
# Tru Optik > Webbula > Passionate About > Science > Weather
# Tru Optik > Webbula > Passionate About > Shopping > Coupons
# Tru Optik > Webbula > Passionate About > Shopping > Fashion
# Tru Optik > Webbula > Passionate About > Sports
# Tru Optik > Webbula > Passionate About > Sports & Leisure
# Tru Optik > Webbula > Passionate About > Sports > Baseball
# Tru Optik > Webbula > Passionate About > Sports > Basketball
# Tru Optik > Webbula > Passionate About > Sports > Boating & Sailing
# Tru Optik > Webbula > Passionate About > Sports > Football
# Tru Optik > Webbula > Passionate About > Sports > Hockey
# Tru Optik > Webbula > Passionate About > Sports > Motor Sports
# Tru Optik > Webbula > Passionate About > Sports > NASCAR
# Tru Optik > Webbula > Passionate About > Sports > Scuba Diving
# Tru Optik > Webbula > Passionate About > Sports > Soccer
# Tru Optik > Webbula > Passionate About > Sports > Tennis
# Tru Optik > Webbula > Passionate About > Sports > Watching Sports
# Tru Optik > Webbula > Passionate About > Travel
# Tru Optik > Webbula > Passionate About > Travel > Air Travel
# Tru Optik > Webbula > Passionate About > Travel > Cruises
# Tru Optik > Webbula > Passionate About > Travel > Hotels
# Tru Optik > Webbula > Passionate About > Travel > International
# Tru Optik > Webbula > Passionate About > Travel > USA
# Tru Optik > Webbula > Passionate About > Vehicles > Automobiles
# Tru Optik > Webbula > Passionate About > Vehicles > Motorcycles
# Tru Optik > Webbula > Politics > Leaning Democrat
# Tru Optik > Webbula > Politics > Leaning Independent
# Tru Optik > Webbula > Politics > Leaning Republican
# Tru Optik > Webbula > Politics > Swing Voters
# Tru Optik > Webbula > Politics > Undecided
# Tru Optik > Webbula > Shopper Currently Seeking > Collectibles
# Tru Optik > Webbula > Shopper Currently Seeking > Collectibles > Art
# Tru Optik > Webbula > Shopper Currently Seeking > Collectibles > Avid Collectors
# Tru Optik > Webbula > Shopper Currently Seeking > Financial Products > Insurance > Auto
# Tru Optik > Webbula > Shopper Currently Seeking > Financial Products > Insurance > Health
# Tru Optik > Webbula > Shopper Currently Seeking > Retail > Apparel > Children's
# Tru Optik > Webbula > Shopper Currently Seeking > Retail > Automotive; Car Parts & Accessories
# Tru Optik > Webbula > B2B > Industry > Agriculture; Forestry; Fishing and Hunting
# Tru Optik > Webbula > B2B > Industry > Retail Trade > Furniture and Home Furnishings Stores
# Tru Optik > Webbula > B2B > Title|Career|Role > Administration Executive
# Tru Optik > Webbula > B2B > Title|Career|Role > Chief Administrative Officer
# Tru Optik > Webbula > B2B > Title|Career|Role > Chief Executive Officer
# Tru Optik > Webbula > B2B > Title|Career|Role > Chief Financial Officer
# Tru Optik > Webbula > B2B > Title|Career|Role > Chief Marketing Officer
# Tru Optik > Webbula > B2B > Title|Career|Role > Chief Operating Officer
# Tru Optik > Webbula > B2B > Title|Career|Role > Corporate Communications Executive
# Tru Optik > Webbula > B2B > Title|Career|Role > Director
# Tru Optik > Webbula > B2B > Title|Career|Role > Engineering/Technical
# Tru Optik > Webbula > B2B > Title|Career|Role > Executive Director
# Tru Optik > Webbula > B2B > Title|Career|Role > Executive Officer
# Tru Optik > Webbula > B2B > Title|Career|Role > Executive Vice President
# Tru Optik > Webbula > B2B > Title|Career|Role > Finance Executive
# Tru Optik > Webbula > B2B > Title|Career|Role > General Manager
# Tru Optik > Webbula > B2B > Title|Career|Role > Human Resources Executive
# Tru Optik > Webbula > B2B > Title|Career|Role > IT Executive
# Tru Optik > Webbula > B2B > Title|Career|Role > Manager
# Tru Optik > Webbula > B2B > Title|Career|Role > Manufacturing Executive
# Tru Optik > Webbula > B2B > Title|Career|Role > Marketing Executive
# Tru Optik > Webbula > B2B > Title|Career|Role > Office Manager
# Tru Optik > Webbula > B2B > Title|Career|Role > Operations Executive
# Tru Optik > Webbula > B2B > Title|Career|Role > President
# Tru Optik > Webbula > B2B > Title|Career|Role > Purchasing Executive
# Tru Optik > Webbula > B2B > Title|Career|Role > Sales Executive
# Tru Optik > Webbula > B2B > Title|Career|Role > Senior Vice President
# Tru Optik > Webbula > B2B > Title|Career|Role > Site Manager
# Tru Optik > Webbula > B2B > Title|Career|Role > Telecommunications Executive
# Tru Optik > Webbula > B2B > Title|Career|Role > Vice President
# Tru Optik > Webbula > B2B Premium > Company > Manufacturing > Consumer Products > Auto|Car|Vehicles & Vehicle Components
# Tru Optik > Webbula > B2B Premium > Company > Manufacturing > Defense & Law Enforcement > Military Equipment
# Tru Optik > Webbula > B2B Premium > Company > Manufacturing > Engineering Equipment > Automation Systems
# Tru Optik > Webbula > B2B Premium > Company > Manufacturing > Industry Served > Automotive Industry
# Tru Optik > Webbula > B2B Premium > Company > Manufacturing > Industry Served > Environmental Industry
# Tru Optik > Webbula > B2B Premium > Employment > Unemployed
# Tru Optik > Webbula > B2B Premium > Functional Area > C-Suite
# Tru Optik > Webbula > B2B Premium > Functional Area > Finance
# Tru Optik > Webbula > B2B Premium > Functional Area > Finance > Banking
# Tru Optik > Webbula > B2B Premium > Functional Area > Finance > Investment Banking
# Tru Optik > Webbula > B2B Premium > Functional Area > Finance > Wealth Management
# Tru Optik > Webbula > B2B Premium > Functional Area > Medical / Health
# Tru Optik > Webbula > B2B Premium > Industry|Occupation|Career|Job > Colleges & Universities
# Tru Optik > Webbula > B2B Premium > Industry|Occupation|Career|Job > Finance
# Tru Optik > Webbula > B2B Premium > Industry|Occupation|Career|Job > Healthcare
# Tru Optik > Webbula > B2B Premium > Industry|Occupation|Career|Job > Investment Banking
# Tru Optik > Webbula > B2B Premium > Occupation > Active Military
# Tru Optik > Webbula > B2B Premium > Occupation > Active Military > Air Force
# Tru Optik > Webbula > B2B Premium > Occupation > Active Military > Army
# Tru Optik > Webbula > B2B Premium > Occupation > Active Military > Coast Guard
# Tru Optik > Webbula > B2B Premium > Occupation > Active Military > Marines
# Tru Optik > Webbula > B2B Premium > Occupation > Active Military > Navy
# Tru Optik > Webbula > B2B Premium > Occupation > Education > Teacher
# Tru Optik > Webbula > B2B Premium > Occupation > Health > Dental Assistant
# Tru Optik > Webbula > B2B Premium > Occupation > Health > Dental Hygienist
# Tru Optik > Webbula > B2B Premium > Occupation > Health > Nurse
# Tru Optik > Webbula > B2B Premium > Occupation > Sales > Real Estate Agents / Brokers
# Tru Optik > Webbula > B2B Premium > Professional Groups > Medical Directors
# Tru Optik > Webbula > B2B Premium > Roles > Business Owner
# Tru Optik > Webbula > B2B Premium > Roles > Seniority > Executives
# Tru Optik > Alliant > Demographics > Age 25-29 years
# Tru Optik > Alliant > Demographics > Age 30-34 years
# Tru Optik > Alliant > Demographics > Age 35-39 years
# Tru Optik > Alliant > Demographics > Age 40-44 years
# Tru Optik > Alliant > Demographics > Age 45-49 years
# Tru Optik > Alliant > Demographics > Age 50-54 years
# Tru Optik > Alliant > Propensity > Fashionistas
# Tru Optik > Alliant > Propensity > Home Depot Buyer Propensity
# Tru Optik > Alliant > Propensity > Lowes Buyer Propensity
# Tru Optik > Alliant > Propensity > Bed Bath and Beyond Buyer Propensity
# Tru Optik > Alliant > Propensity > Petco Buyer Propensity
# Tru Optik > Alliant > Propensity > Spectrum Buyer Propensity
# Tru Optik > Lotame > Advanced Demographics > Declared Parents
# Tru Optik > Lotame > Advanced Demographics > Dads
# Tru Optik > Lotame > Advanced Demographics > Moms
# Tru Optik > Lotame > Advanced Demographics > Parents of Infants
# Tru Optik > Lotame > vCE Optimized > Lotame_vCE Optimized_Age: 18-24_M
# Tru Optik > Infogroup > Seniority > Director
# Tru Optik > Infogroup > Seniority > C-Level
# Tru Optik > Infogroup > Functional Area > Education > Professors and Teachers
# Tru Optik > Infogroup > Occupation > Currently Employed > Employment Level > C-Level Executive Employee Level -- Co-op Sourced
# Tru Optik > Infogroup > Functional Area > Medical and Health Services > Physicians
# Tru Optik > Infogroup > Decision Makers > C-Level Decision Makers -- Coop Sourced
# Tru Optik > Infogroup > Industry > Banking and Finance
# Tru Optik > Infogroup > Functional Area > Banking > Investment Banking
# Tru Optik > Infogroup > Decision Makers > Medical & Health Services -- Co-op Sourced Decision Makers
# Tru Optik > Infogroup > Seniority > Vice President
# Tru Optik > Infogroup > Functional Area > Medical and Health Services
# Tru Optik > Infogroup > Decision Makers > Finance Decision Makers
# Tru Optik > Kantar - Shopcom > CPG > Auto-Fluids Antifreeze and Waxes
# Tru Optik > Kantar - Shopcom > Auto Aftermarket > Tires
# Tru Optik > Kantar - Shopcom > Home Improvement > Tools And Hardware > All Tools
# Tru Optik > Kantar - Shopcom > Retail > Jewelry And Watches
# Tru Optik > Kantar - Shopcom > Over The Counter Remedies > Contraceptives - Family Planning - Sexual Wellness
# Tru Optik > Kantar - Shopcom > Over The Counter Remedies > Home Medical Care Accessories
# Tru Optik > Kantar - Shopcom > Over The Counter Remedies > Nutritional Supplements And Weight Control
# Tru Optik > Kantar - Shopcom > Sporting Goods And Outdoor > Outdoor Recreation > Camping Equipment
# Tru Optik > Kantar - Shopcom > Sporting Goods And Outdoor > Sporting Goods > Exercise Equipment
# Tru Optik > Lotame > Advanced Demographics > Parents of Pre-Teens
# Tru Optik > Lotame > Advanced Demographics > Parents of Teenagers
# Tru Optik > Lotame > Advanced Demographics > Parents of Toddlers
# Tru Optik > Lotame > Advanced Demographics > Parents of Young Children
# Tru Optik > Lotame > Advanced Demographics > Pet Owners
# Tru Optik > Lotame > Advanced Demographics > Level of Education - High School
# Tru Optik > Lotame > Advanced Demographics > Level of Education - Some College
# Tru Optik > Lotame > Advanced Demographics > Relationship Status - Engaged
# Tru Optik > Lotame > Advanced Demographics > Relationship Status - Married
# Tru Optik > Lotame > Advanced Demographics > HHI Less Than 25k
# Tru Optik > Lotame > Advanced Demographics > HHI 75k-100k
# Tru Optik > Lotame > Advanced Demographics > HHI 100k+
# Tru Optik > Lotame > Advanced Demographics > HHI 150k-250k
# Tru Optik > Lotame > Advanced Demographics > HHI 250k+
# Tru Optik > Lotame > Advanced Demographics > Moved Within Last 6 Months
# Tru Optik > Lotame > Advanced Demographics > Primary Residence - Owns
# Tru Optik > Lotame > Advanced Demographics > Ethnicity - African-American
# Tru Optik > Lotame > Advanced Demographics > Ethnicity - Hispanic
# Tru Optik > Lotame > Advanced Demographics > Hispanic or Spanish Speakers
# Tru Optik > Lotame > Advanced Demographics > Credit Level - Excellent
# Tru Optik > Lotame > Advanced Demographics > Credit Level - Good
# Tru Optik > Lotame > Advanced Demographics > Home Value - 0k-200k
# Tru Optik > Lotame > Advanced Demographics > Home Value - 200k-400k
# Tru Optik > Lotame > Advanced Demographics > Home Value - 400k-750k
# Tru Optik > Lotame > Advanced Demographics > Home Value - 750k+
# Tru Optik > Lotame > Arts & Culture > Photography
# Tru Optik > Lotame > Automobiles > Compact-Sized Cars
# Tru Optik > Lotame > Automobiles > Full-Sized Cars
# Tru Optik > Lotame > Automobiles > Hybrid Cars
# Tru Optik > Lotame > Automobiles > Luxury Cars
# Tru Optik > Lotame > Automobiles > Mid-Sized Cars
# Tru Optik > Lotame > Automobiles > Motorcycles
# Tru Optik > Lotame > Automobiles > Sport Utility Vehicles
# Tru Optik > Lotame > Automobiles > Sports Cars
# Tru Optik > Lotame > Automobiles > Trucks
# Tru Optik > Lotame > Automobiles > Vans & Minivans
# Tru Optik > Lotame > Business > Business - Finance Professionals
# Tru Optik > Lotame > Business > Job Seekers
# Tru Optik > Lotame > Demographics > Age : 18-24
# Tru Optik > Lotame > Demographics > Gender: Female
# Tru Optik > Lotame > Entertainment > Action & Adventure Movies
# Tru Optik > Lotame > Entertainment > Children & Family Movie Fans
# Tru Optik > Lotame > Entertainment > Comedy Movies
# Tru Optik > Lotame > Entertainment > Drama Movies
# Tru Optik > Lotame > Entertainment > Romance Movies
# Tru Optik > Lotame > Entertainment > Sci-Fi Movies
# Tru Optik > Lotame > Entertainment > Summer Blockbusters
# Tru Optik > Lotame > Entertainment > Country Music
# Tru Optik > Lotame > Entertainment > Hip Hop & Rap Music
# Tru Optik > Lotame > Entertainment > Pop Music
# Tru Optik > Lotame > Entertainment > Rock Music
# Tru Optik > Lotame > Entertainment > Music Festivals
# Tru Optik > Lotame > Entertainment > All Olympic Sports
# Tru Optik > Lotame > Entertainment > Baseball
# Tru Optik > Lotame > Entertainment > Basketball
# Tru Optik > Lotame > Entertainment > Boxing
# Tru Optik > Lotame > Entertainment > College Sports
# Tru Optik > Lotame > Entertainment > Cricket
# Tru Optik > Lotame > Entertainment > Cycling
# Tru Optik > Lotame > Entertainment > Fantasy Sports
# Tru Optik > Lotame > Entertainment > American Football
# Tru Optik > Lotame > Entertainment > Golf
# Tru Optik > Lotame > Entertainment > Hockey
# Tru Optik > Lotame > Entertainment > Ice Skating
# Tru Optik > Lotame > Entertainment > Martial Arts
# Tru Optik > Lotame > Entertainment > Motor Sports
# Tru Optik > Lotame > Entertainment > Rugby
# Tru Optik > Lotame > Entertainment > Skiing
# Tru Optik > Lotame > Entertainment > Snowboarding
# Tru Optik > Lotame > Entertainment > American Soccer (Football)
# Tru Optik > Lotame > Entertainment > Summer Olympic Sports
# Tru Optik > Lotame > Entertainment > Tennis and Racket Sports
# Tru Optik > Lotame > Entertainment > Track and Field
# Tru Optik > Lotame > Entertainment > Volleyball
# Tru Optik > Lotame > Entertainment > Water Sports
# Tru Optik > Lotame > Entertainment > Weightlifting
# Tru Optik > Lotame > Entertainment > Winter Olympic Ice Hockey
# Tru Optik > Lotame > Entertainment > Winter Olympic Skiing
# Tru Optik > Lotame > Entertainment > Winter Olympic Sports
# ...
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize CUV Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize CUV Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Sports Car Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Pickup Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Compact Car Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Compact CUV Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Fullsize Car Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize CUV Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize CUV Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 1/2 ton Fullsize Pickup Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize SUV Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Car Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Exotic Car Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 3/4 or 1 ton Fullsize Pickup Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact CUV Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Fullsize SUV Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize Car Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact Car Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 3/4 or 1 ton Fullsize Van Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 3/4 or 1 ton Fullsize Pickup Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Compact CUV Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Van Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Sports Car Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 3/4 or 1 ton Fullsize Van Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Fullsize SUV Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Compact Car Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Subcompact Car Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact Van Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Fullsize Prestige Car Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Fullsize SUV Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize CUV Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize Car Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Pickup Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact Car Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 1/2 ton Fullsize Pickup Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize CUV Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Fullsize Prestige Car Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact Van Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact CUV Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 1/2 ton Fullsize Van Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Car Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Fullsize Car Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 3/4 or 1 ton Fullsize Pickup Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Exotic Car Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize SUV Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Subcompact Car Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Sports Car Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Subcompact Car Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact CUV Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Fullsize Car Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Van Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 1/2 ton Fullsize Van Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact Car Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 1/2 ton Fullsize Pickup Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Pickup Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Compact CUV Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Sports Car Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Compact Car Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Fullsize SUV Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Subcompact Car Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Fullsize Car Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact SUV Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 1/2 ton Fullsize Van Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Fullsize Car Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact SUV Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Pickup Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Sports Car Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Compact Car Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize SUV Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 1/2 ton Fullsize Van Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Van Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact SUV Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize CUV Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Fullsize Prestige Car Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize SUV Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Compact CUV Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize Car Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Sports Car Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize Car Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Subcompact Car Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize SUV Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Sports Car Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Exotic Car Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Car Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Sports Car Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize SUV Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize CUV Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Fullsize Prestige Car Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Subcompact Car Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 1/2 ton Fullsize Pickup Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Fullsize SUV Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Subcompact Car Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact Van Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 3/4 or 1 ton Fullsize Pickup Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Sports Car Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact SUV Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Van Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Exotic Car Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Sports Car Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact Van Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact CUV Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 3/4 or 1 ton Fullsize Van Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize SUV Rank 4
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact Car Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Sports Car Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Subcompact Car Rank 3
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Car Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Fullsize SUV Rank 1
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 3/4 or 1 ton Fullsize Van Rank 2
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize SUV Rank 3
# Tru Optik > Polk IHSM > Garage Predictor > Acura
# Tru Optik > Polk IHSM > Garage Predictor > Audi
# Tru Optik > Polk IHSM > Garage Predictor > BMW
# Tru Optik > Polk IHSM > Garage Predictor > Buick
# Tru Optik > Polk IHSM > Garage Predictor > Cadillac
# Tru Optik > Polk IHSM > Garage Predictor > Chevrolet division car
# Tru Optik > Polk IHSM > Garage Predictor > Chevrolet division truck
# Tru Optik > Polk IHSM > Garage Predictor > Chrysler division vehicle
# Tru Optik > Polk IHSM > Garage Predictor > Dodge division car
# Tru Optik > Polk IHSM > Garage Predictor > Dodge division truck
# Tru Optik > Polk IHSM > Garage Predictor > Fiat Chrysler Automobiles corporation vehicle
# Tru Optik > Polk IHSM > Garage Predictor > Ford corporation vehicle
# Tru Optik > Polk IHSM > Garage Predictor > Ford division car
# Tru Optik > Polk IHSM > Garage Predictor > Ford division truck
# Tru Optik > Polk IHSM > Garage Predictor > GM corporation vehicle
# Tru Optik > Polk IHSM > Garage Predictor > GMC division vehicle
# Tru Optik > Polk IHSM > Garage Predictor > Honda
# Tru Optik > Polk IHSM > Garage Predictor > Hummer
# Tru Optik > Polk IHSM > Garage Predictor > Hyundai
# Tru Optik > Polk IHSM > Garage Predictor > Infiniti
# Tru Optik > Polk IHSM > Garage Predictor > Isuzu
# Tru Optik > Polk IHSM > Garage Predictor > Jaguar
# Tru Optik > Polk IHSM > Garage Predictor > Jeep/Eagle
# Tru Optik > Polk IHSM > Garage Predictor > Kia
# Tru Optik > Polk IHSM > Garage Predictor > Land Rover
# Tru Optik > Polk IHSM > Garage Predictor > Lexus
# Tru Optik > Polk IHSM > Garage Predictor > Lincoln
# Tru Optik > Polk IHSM > Garage Predictor > Mazda
# Tru Optik > Polk IHSM > Garage Predictor > Mercedes
# Tru Optik > Polk IHSM > Garage Predictor > Mercury
# Tru Optik > Polk IHSM > Garage Predictor > Mini
# Tru Optik > Polk IHSM > Garage Predictor > Mitsubishi
# Tru Optik > Polk IHSM > Garage Predictor > Nissan
# Tru Optik > Polk IHSM > Garage Predictor > Oldsmobile
# Tru Optik > Polk IHSM > Garage Predictor > Plymouth
# Tru Optik > Polk IHSM > Garage Predictor > Pontiac
# Tru Optik > Polk IHSM > Garage Predictor > Porsche
# Tru Optik > Polk IHSM > Garage Predictor > Saab
# Tru Optik > Polk IHSM > Garage Predictor > Saturn
# Tru Optik > Polk IHSM > Garage Predictor > Subaru
# Tru Optik > Polk IHSM > Garage Predictor > Suzuki
# Tru Optik > Polk IHSM > Garage Predictor > Toyota
# Tru Optik > Polk IHSM > Garage Predictor > Volkswagen
# Tru Optik > Polk IHSM > Garage Predictor > Volvo
# Tru Optik > Polk IHSM > Garage Predictor > Convertible
# Tru Optik > Polk IHSM > Garage Predictor > Coupe
# Tru Optik > Polk IHSM > Garage Predictor > Luxury compact car
# Tru Optik > Polk IHSM > Garage Predictor > Luxury compact CUV
# Tru Optik > Polk IHSM > Garage Predictor > Luxury exotic car
# Tru Optik > Polk IHSM > Garage Predictor > Luxury full-size car
# Tru Optik > Polk IHSM > Garage Predictor > Luxury full-size SUV
# Tru Optik > Polk IHSM > Garage Predictor > Luxury mid-size car
# Tru Optik > Polk IHSM > Garage Predictor > Luxury mid-size CUV
# Tru Optik > Polk IHSM > Garage Predictor > Luxury mid-size SUV
# Tru Optik > Polk IHSM > Garage Predictor > Luxury prestige full-size car
# Tru Optik > Polk IHSM > Garage Predictor > Luxury sporty car
# Tru Optik > Polk IHSM > Garage Predictor > Luxury subcompact car
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury compact car
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury compact CUV
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury compact pickup
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury compact SUV
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury compact van
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury full-size 1/2 ton pickup
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury full-size 3/4 -1 ton van
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury full-size 3/4 or 1 ton pickup
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury full-size car
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury full-size half ton van
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury full-size SUV
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury mid-size car
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury mid-size CUV
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury mid-size pickup
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury mid-size SUV
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury mid-size van
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury sport mid-size car
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury sporty car
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury subcompact car
# Tru Optik > Polk IHSM > Garage Predictor > Sedan
# Tru Optik > comScore > Demographics > Males: 18-24
# Tru Optik > comScore > Demographics > Females: 18-24
# Tru Optik > comScore > Demographics > Females: 18-34
# Tru Optik > comScore > Demographics > Females: 18-49
# Tru Optik > comScore > Demographics > Females: 18+
# Tru Optik > comScore > Demographics > Females: 21-34
# Tru Optik > comScore > Demographics > Females: 21-49
# Tru Optik > comScore > Demographics > Females: 25-34
# Tru Optik > comScore > Demographics > Females: 25-49
# Tru Optik > comScore > Demographics > Females: 35-49
# Tru Optik > comScore > Demographics > Females: 50+
# Tru Optik > comScore > Demographics > Persons: 18-24
# Tru Optik > comScore > Demographics > Persons: 18-34
# Tru Optik > Netwise > Professionals > Senior Execs & Board Members
# Tru Optik > Dataline > Buyers > Computer & Technology Buyer
# Tru Optik > Webbula > Passionate About > Business & Finance > Investing > Foreign
# Tru Optik > Webbula > Passionate About > Business & Finance > Money Seekers
# Tru Optik > Webbula > B2B > Corporate Structure > Business Firm
# Tru Optik > Webbula > B2B > Ownership Type > Privately Traded Company
# Tru Optik > Webbula > B2B Premium > Company > Classification > U.S. Government Supplier
# Tru Optik > Webbula > B2B Premium > Company > Technologies Used > Marketing Performance Management > Business Intelligence
# Tru Optik > Webbula > B2B Premium > Company > Technologies Used > Web Oriented Architecture
# Tru Optik > Webbula > B2B Premium > Company > Technologies Used > Web Oriented Architecture > Web & Portal
# Tru Optik > Webbula > B2B Premium > Company Size > Medium
# Tru Optik > Webbula > B2B Premium > Functional Area > Government
# Tru Optik > Webbula > B2B Premium > Functional Area > Government > Elected Officials
# Tru Optik > Webbula > B2B Premium > Industry|Occupation|Career|Job > Government
# Tru Optik > Infogroup > Industry > Business Services > Marketing; Advertising and Sales
# Tru Optik > Infogroup > Company > Specialty > Small Businesses
# Tru Optik > Infogroup > Decision Makers > Small Business Decision Makers
# Tru Optik > Infogroup > Decision Makers > Business Buyers > Frequent Transactional Business Buyers - Education (I)
# Tru Optik > Infogroup > Technology Onsite > Software > Antivirus -- Co-op Sourced
# Tru Optik > Infogroup > Decision Makers > Very Small Business Decision Makers -- Co-op Sourced
# Tru Optik > Infogroup > Occupation > Currently Employed > Functional Area > Marketing & Comm > Sales and Business Development
# Tru Optik > Lotame > Business > Business - IT Professionals
# Tru Optik > Lotame > Business > Business - Small Business Professionals
# Tru Optik > Lotame > Business > Career & Employment
# Tru Optik > Lotame > Business to Business (B2B) > B2B Decision Makers - IT Decision Makers
# Tru Optik > Lotame > Business to Business (B2B) > B2B Decision Makers - Sales and Marketing Decision Makers
# Tru Optik > Lotame > Business to Business (B2B) > B2B Decision Makers - Small Business Decision Makers
# Tru Optik > Lotame > Technology > Computers & Technology
# Tru Optik > Lotame > Technology > Home Audio & Video

# %%
#BLOCK 3: CREATE DICTIONARY BASED ON UNIQUE CATEGORIES AND WRITE TO XL FILE
#ONLY RUN THIS BLOCK AFTER EDITS HAVE BEEN MADE TO CSV CREATED IN PREVIOUS BLOCK

#convert corrected csv to excel file so we can write into it
merge_csv_to_a_book([correctedfile],correctedfile_excel)


#create dictionary
category_dict = {}
corrected_csv = open(correctedfile)
for line in corrected_csv:
    line = line.replace('"""Fashion/Style, Apparel, Accessories"""', ',Fashion/Style; Apparel; Accessories').replace(',,',',').strip()
    if len(line.split(',')) > 3:
        line = line.replace('Style,','Style;').replace('Apparel,','Apparel;')
    line = line.split(',')
    attribute, category=line[:2]
    category = replacements(category)
    
    usage=int(line[2])
    if category in list(category_dict.keys()):
        category_dict[category] += usage
    elif category not in list(category_dict.keys()):
        category_dict[category] = usage
    else:
        print('sumthin fucky')

wb = load_workbook(correctedfile_excel)
ws = wb.active
for key, value in category_dict.items():
    index = list(category_dict.keys()).index(key)+1
    ws.cell(row = index, column = 4).value = key
    ws.cell(row = index, column = 5).value = value

wb.save(finalfile)
# Out:
# /Users/default/anaconda/lib/python3.6/site-packages/openpyxl/workbook/child.py:102: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %%
#SIDE PROJECT: CREATE A DATABASE OF VALUES THAT HAVE CORRECT LABELS
#RUN ONLY ONCE: THIS WILL OVERWRITE THE CURRENT DATABASE
folder_path = '/Users/default/Documents/PythonMisc/Videology Reports - Completed'
folder_contents = os.listdir(folder_path)
#all files are excel, openpyxl will be used

#also, we have to load our database so we know what we have/don't
db_path = '/Users/default/Documents/PythonMisc/VideologyDatabase.xlsx'
db_file = load_workbook(db_path)
db_ws = db_file.active
db_contents = {}
pattern = '^[Ee]'

print(len(db_contents))
for attribute, category in [[i.value for i in x] for x in db_ws.iter_rows(max_col=2)]:
    db_contents[attribute] = category

for file in folder_contents:
    if re.match(pattern, file):
        wb = load_workbook(folder_path + '/' + file)
        ws = wb.active

        #only want the first 2 columns (attribute and category)
        for attribute, category in [[i.value for i in x] for x in ws.iter_rows(max_col=2)]:
            if attribute is None:
                attribute = 'TEST'
                category = 'TEST'
            if '>' == attribute[-1]:
                attribute = attribute[:-2]
            try:
                category = replacements(category)
            except:
                print('no bueno')
            db_contents[attribute] = category
            '''
            if attribute in list(db_contents.keys()):
                pass
            elif attribute not in list(db_contents.keys()):
                db_contents[attribute] = category
            '''
print(len(db_contents))
#Now, we write the completed dictionary to the database file again
for i, (key, value) in enumerate(db_contents.items()):
    db_ws.cell(row=i+1, column = 1).value = key
    db_ws.cell(row=i+1, column = 2).value = value
    
db_file.save(db_path)

#pattern = '^[Ee]'
#for file in folder_contents:
#    if re.match(pattern, file):
#        print(file)
# Out:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-82dab72968d7> in <module>()
#      15
#      16 for file in folder_contents:
# ---> 17     if re.match(pattern, file):
#      18         wb = load_workbook(folder_path + '/' + file)
#      19         ws = wb.active
#
# NameError: name 'pattern' is not defined

# %%
#FIX THE 2017 REPORTS
folder = '/Users/default/Documents/PythonMisc/Videology Reports - Completed'
for testfile in [x for x in os.listdir(folder) if x[0] != '.' and x[:2] != '~$' and x[0] != '2']:
    #print(testfile)
    exp_testfile = '/'.join(testfile.split('/')[:-1])+'/Experimental-'+testfile.split('/')[-1]
    #print(folder+'/'+testfile[2:])
    if '~$' in testfile:
        print(testfile)
        testfile = testfile[15:]
    wb = load_workbook(folder+'/'+testfile)
    ws = wb.active
    cdict = {}

    for i,row in enumerate(ws.iter_rows(max_col = 3),start=1):
        attr, category, usage = [x.value for x in row]
        if all([attr,category,usage]):
            category = replacements(category)
            if 'hhi' in attr.lower() or 'income' in attr.lower():
                category = 'Income'
                ws.cell(row=i,column=2).value = 'Income'
            if category in list(cdict.keys()):
                cdict[category] += usage
            elif category not in list(cdict.keys()):
                cdict[category] = usage
        else:
            print('One of the values is None')
    for i,(key, value) in enumerate(cdict.items(),start=1):
        ws.cell(row = i, column = 6).value = key
        ws.cell(row = i, column = 7).value = value
        ##print(ws.cell(row = i, column = 6).value)
        ##print(ws.cell(row = i, column = 7).value)

    wb.save(folder+exp_testfile)
# Out:
# /Users/default/anaconda/lib/python3.6/site-packages/openpyxl/workbook/child.py:102: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %%
folder = '/Users/default/Documents/PythonMisc/Videology Reports - Completed/Correct Category Values 2017'
for file in os.listdir(folder):
    print(file)
    print(file[13:])
    os.rename(folder+'/'+file, folder+'/'+file[13:])
    
    #os.rename(folder+'/'+file, folder+'/'+file[11:])
# Out:
# Experimental-Edited - August2017TestData.xlsx
# Edited - August2017TestData.xlsx
# Experimental-Edited - July2017TestDat.xlsx
# Edited - July2017TestDat.xlsx
# Experimental-Edited - Dec2017Categories copy.xlsx
# Edited - Dec2017Categories copy.xlsx
# Experimental-Edited - Nov2017TestData.xlsx
# Edited - Nov2017TestData.xlsx
# Experimental-Edited - Sept2017TestData.xlsx
# Edited - Sept2017TestData.xlsx
# Experimental-Edited - Oct2017TestData.xlsx
# Edited - Oct2017TestData.xlsx

# %%
#folder = '/Users/default/Documents/PythonMisc/Videology Reports - Completed'
#files = [file for file in os.listdir(folder) if '2017' in file]

# for file in files:
#     print(file)
#     wb = load_workbook(folder+'/'+file)
#     ws = wb.active
#     cdict = {}   
#     for i,row in enumerate([[i.value for i in x[:3]] for x in ws.iter_rows()], start=1):
#         #print([x[0].value for x in ws.iter_rows()].index(row[0]))
#         if row[1]:
#             row[1] = replacements(row[1]) 
#         if row[0] and ('hhi' in row[0].lower() or 'income' in row[0].lower()):
#             ws.cell(row=i, column=2).value = 'Income'
#             #print(ws.cell(row=i, column=2).value)
#             row[1] = 'Income'
#     for category, usage in [[i.value for i in x[1:3]] for x in ws.iter_rows()]:
#         if category and usage:
#             print(category)
#             if category in list(cdict.keys()):
#                 cdict[category] += usage
#             elif category not in list(cdict.keys()):
#                 cdict[category] = usage
#         else:
#             pass   
#     print(len(cdict))
#     wb.save(folder+'/Experimental'+file)
# Out:
# Edited - Oct2017TestData.xlsx
# Edited - Dec2017Categories copy.xlsx
# Edited - Sept2017TestData.xlsx
# Edited - Nov2017TestData.xlsx
# Edited - August2017TestData.xlsx
# Edited - July2017TestDat.xlsx
# /Users/default/Documents/PythonMisc/Videology Reports - Completed/Experimental-Edited - July2017TestDat.xlsx
# One of the values is None
# One of the values is None
# One of the values is None
# ('Auto', 35113)
# Auto
# 35113
# ('Health & Fitness/Wellness', 854)
# Health & Fitness/Wellness
# 854
# ('Home Imp/Décor/Home & Garden/Home&Fam/DIY', 9863)
# Home Imp/Décor/Home & Garden/Home&Fam/DIY
# 9863
# ('Demo', 482287)
# Demo
# 482287
# ('Entertainment & Media', 35375)
# Entertainment & Media
# 35375
# ('Retail', 243452)
# Retail
# 243452
# ('Career & Education', 125678)
# Career & Education
# 125678

# %%
#  SIDE PROJECT #2: CREATE SEPARATE CATEGORY FOR INCOME VALUES AND WRITE THOSE TO THE EXCEL FILE
folder = '/Users/default/Documents/PythonMisc/Videology Reports - Completed'
files = [file for file in os.listdir(folder) if file[0] != '.']
for file in files:
    print(file)
    wrkbk = load_workbook(folder+'/'+file)
    wsht = wrkbk.active
    for i,row in enumerate(wsht.iter_rows(max_col=3)):
        try:
            category = row[1].value.lower()
        except:
            pass
        if 'hhi' in category or 'income' in category:
            wsht.cell(row=i+1, column=2).value = 'Income'
    
    
    wrkbk.save(folder+'/'+file)
# Out:
# ExperimentalEdited - Sept2017TestData.xlsx
# 7
# Edited - Oct2017TestData.xlsx
# 7
# ExperimentalEdited - Nov2017TestData.xlsx
# 7
# Edited - MarchCategories.xlsx
# 7
# Edited - May 2018Categories.xlsx
# 7
# ExperimentalEdited - July2017TestDat.xlsx
# 7
# Edited - Dec2017Categories copy.xlsx
# 7
# Edited - Sept2017TestData.xlsx
# 7
# Edited - Nov2017TestData.xlsx
# 7
# ExperimentalEdited - Oct2017TestData.xlsx
# 7
# Edited - JanCategories.xlsx
# 7
# Edited - August2017TestData.xlsx
# 7
# ExperimentalEdited - Dec2017Categories copy.xlsx
# 7
# ExperimentalEdited - August2017TestData.xlsx
# 7
# Final - June2018Categories.xlsx
# 7
# Edited - TruOptik - Monthly Usage - May 2018.xlsx
# 7
# Edited - July2017TestDat.xlsx
# 7
# Edited - AprilCategories.xlsx
# 7
# Edited - FebCategories.xlsx
# 7
# Edited - June2018Categories.xlsx
# 7
# /Users/default/anaconda/lib/python3.6/site-packages/openpyxl/workbook/child.py:102: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
