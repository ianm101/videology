# %%
#import libraries / dependencies
import openpyxl
from openpyxl import load_workbook, Workbook
import csv
from pyexcel.cookbook import merge_all_to_a_book, merge_csv_to_a_book
import os
import re
import keras

# %%
#FUNCTIONS BLOCK

#get_filenames: 
#Arguments: raw data filepath (absolute)
#Returns: A tuple of strings representing the files that will be used to 
#represent the data at each step of refinement
def get_filenames(rdfile):
    #EXAMPLE '/Users/default/Downloads/Videology Reports/TruOptik - Monthly Usage - June 2018.xlsx'
    rd = rdfile.split('/')
    path = '/'.join(rd[:-1])
    extractedfile = path+'/Extracted-'+rd[-1][:-4]+'csv'
    correctedfile = path+'/Corrected-'+rd[-1][:-4]+'csv'
    finalfile = path+'/Final-'+rd[-1]
    correctedfile_excel = path+'/Corrected-'+rd[-1]
    return extractedfile, correctedfile, finalfile, correctedfile_excel

#replacements:
#Argument: the videology category (string)
#Returns: the category with all necessary corrections (string)
#Basically there are duplicates in the categories that are *slightly* different
#and this takes care of those. it's pretty ugly but I haven't thought of a better way yet
def replacements(category):
    category = category.replace('Financial','Financial/Insurance Attributes & Behaviors')
    category = category.replace('Financial/Insurance Attributes & Behaviors/Insurance Attributes & Behaviors','Financial/Insurance Attributes & Behaviors')
    category = category.replace('"','')
    category = category.replace('Home & Garden','Home Imp/Décor/Home & Garden/Home&Fam/DIY').replace('Home Imp/Décor/Home Imp/Décor/Home & Garden/Home&Fam/DIY/Home&Fam/DIY','Home Imp/Décor/Home & Garden/Home&Fam/DIY')
    category = category.replace('Demos','Demo')
    category = category.replace('Sports & Outdoors','Sporting & Healthy Living + Sporting Goods/Outdoor')
    category = category.replace('Education/Career','Education & Career')
    category = category.replace('Entertainment/Media','Entertainment & Media')
    category = category.replace('Fashion & Style', 'Fashion/Style; Apparel; Accessories')
    category = category.replace('Health','Health & Fitness/Wellness').replace('Health & Fitness/Wellness & Fitness/Wellness','Health & Fitness/Wellness')
    return category

# %%
#BLOCK 1: EXTRACT THE ATTRIBUTES, IDS, AND USAGE DATA FROM THE EXCEL SHEET and get unique values. Then store in CSV

#absolute filepath to raw_data (Videology Report)
raw_data = '/Users/default/Downloads/TruOptik - Monthly Usage - July 2018.xlsx'

#This program will create the edited files in the same location as the original, so look there for the data
extractedfile, correctedfile, finalfile, correctedfile_excel = get_filenames(raw_data)

#use openpyxl library to create a workbook object from the xlsx file so we can work w it
rd_wb = load_workbook(raw_data)

#get the worksheet with the data
#usually the sheet is named 'Behavioral Cost', but sometimes there is a trailing space or its named something else
#because Videology is allergic to consistency. Either way changing the string will get you the desired worksheet
rd_ws = rd_wb['Behavioral Cost']

#the header has the names for each column in the worksheet
header = [x.value for x in list(rd_ws.rows)[0]]
print(header)

#we want the index of the columns for the following: 
#Retargeting Attribute
#Attribute ID (sometimes called External Retargeting ID so just change string)
#Usage (sometimes called Billable Usage)
ra_ind = header.index('Retargeting Attribute')
erid_ind= header.index('External Retargeting ID')
usage_ind = header.index('Usage')

print([ra_ind, erid_ind, usage_ind])

#The following block of code creates a dictionary of unique attributes
#Dictionary format is "unique_records[attribute] = usage"

unique_records = {}
for item in [[i.value for i in x] for x in rd_ws.iter_rows(min_row=2)]:
    #edit the row if it exists
    if item[ra_ind] is not None: 
        row = [item[ra_ind].replace(',',';').replace('  ',' '),item[erid_ind],item[usage_ind]]
    else:
        pass
    #check for membership in the dictionary keys
    if row[0] in list(unique_records.keys()):
        #if the usage value is an int, add it to the dictionary (this gets rid of excel formulas)
        if isinstance(item[usage_ind],int):
            unique_records[row[0]] += int(item[usage_ind])
    #otherwise create new entry
    elif row[0] not in list(unique_records.keys()):
        if isinstance(item[usage_ind],int):
            unique_records[row[0]] = int(item[usage_ind])

#write this unique record data to a csv
extracted_data = open(extractedfile,'w')
for kv in unique_records.items():
    write = csv.writer(extracted_data)
    write.writerow(kv)
extracted_data.close()
# Out:
# ['Provider', 'Country', 'Retargeting Attribute', 'External Retargeting ID', 'Device Type', 'Format Type', 'CPU', 'Usage', 'Data Costs', 'Rate Adjustment', 'Adjusted Cost (PC/Mobile)']
# [2, 3, 7]

# %%
#BLOCK 1A: IF THE DATA ISN'T IN A FRIENDLY FORMAT IN THE RAW DATA, INSTEAD USE A SLIGHTLY EDITED VERSION AND CONTINUE FROM THERE
#This block was written because in 1 videology report they had the attribute separated into multiple columns instead of their
#normal format
refined_data = '/Users/default/Documents/PythonMisc/Videology Reports - Completed/Edited - Dec2017Categories copy.xlsx'
wb = load_workbook(refined_data)
ws = wb.active
category_dict = {}
for line in [[i.value for i in x] for x in ws.iter_rows()]:
    if line[1].strip() in list(category_dict.keys()):
        category_dict[line[1].strip()] += int(line[2])
    else:
        category_dict[line[1].strip()] = int(line[2])
for key, value in category_dict.items():
    index = list(category_dict.keys()).index(key) + 1
    ws.cell(row = index, column = 4).value = key
    ws.cell(row = index, column = 5).value = value
wb.save(refined_data)

# %%
#BLOCK 2: CATEGORIZE THE UNIQUE VALUES USING PREVIOUS DATA
#load reference file and create a list of lists of its values

#this block loads an excel file and creates a dictionary in the form: dict[attribute] = category
#with this dictionary we take care of a lot of repeated values so recategorization is easier 
#some new attributes won't be in the database so they might be blank but i'm working on fixing that with another method
db_path = 'VideologyDatabase exp.xlsx'
db_file = load_workbook(db_path)
db_ws = db_file.active
db_contents = {}
for attribute, category in [[i.value for i in x] for x in db_ws.iter_rows(max_col=2)]:
    db_contents[attribute] = category
    
print(len(db_contents))

#load file with missing categories and create list of values
edit_file = open(extractedfile,'r')
corrected_vals = []
for line in edit_file:
    #preprocessing the line
    edited_line = line.replace('"','').strip().split(',',1)
    attribute = edited_line[0]
    usage = edited_line[1]
    #add to corrected values if it is in the database otherwise leave it blank
    try:
        corrected_vals.append([attribute,db_contents[attribute], usage]) 
    except KeyError:
        corrected_vals.append([attribute,'',usage])
        
#write to another file
corrected_file = open(correctedfile,'w')
for value in corrected_vals:
    write = csv.writer(corrected_file)
    write.writerow(value)
corrected_file.close()
# Out:
# 1228

# %%
#BLOCK 3: CREATE DICTIONARY BASED ON UNIQUE CATEGORIES AND WRITE TO XL FILE
#ONLY RUN THIS BLOCK AFTER EDITS HAVE BEEN MADE TO CSV CREATED IN PREVIOUS BLOCK

#convert corrected csv to excel file so we can write into it
merge_csv_to_a_book([correctedfile],correctedfile_excel)


#create dictionary
category_dict = {}
corrected_csv = open(correctedfile)
for line in corrected_csv:
    #more preprocessing
    line = line.replace('"""Fashion/Style, Apparel, Accessories"""', ',Fashion/Style; Apparel; Accessories').replace(',,',',').strip()
    #Some categories have commas which fuck up reading the csv so i replaced them w semicolons
    print(line)
    if len(line.split(',')) > 3:
        line = line.replace('Style,','Style;').replace('Apparel,','Apparel;')
    line = line.split(',')
    if len(line) < 3:
        line.insert(1,'')
    attribute,category = line[:2]
    usage = int(line[2])
    category = replacements(category)
    
    #same dictionary logic as before (should probably be a fcn)
    if category in list(category_dict.keys()):
        category_dict[category] += usage
    elif category not in list(category_dict.keys()):
        category_dict[category] = usage
for k,v in category_dict.items():
    print('Key:', k)
    print('Value:', v)
#now write to an excel file with the dictionary
wb = load_workbook(correctedfile_excel)
ws = wb.active
for key, value in category_dict.items():
    index = list(category_dict.keys()).index(key)+1
    ws.cell(row = index, column = 6).value = key
    ws.cell(row = index, column = 7).value = value

wb.save(finalfile)
# Out:
# /Users/default/anaconda/lib/python3.6/site-packages/openpyxl/workbook/child.py:102: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# Tru Optik > V12Data > Auto Budget > Auto Budget Range <= $29K,Auto,13506
# Tru Optik > V12Data > Auto Budget > Auto Budget Range $30k - $49k,Auto,5769
# Tru Optik > V12Data > Auto Budget > Auto Budget Range >= $50k,Auto,1223
# Tru Optik > V12Data > In Auto Market Predictor > Luxury; Full Size,Auto,17326
# Tru Optik > V12Data > In Auto Market Predictor > Mid Size Car,Auto,184266
# Tru Optik > V12Data > In Auto Market Predictor > Small Car,Auto,153080
# Tru Optik > V12Data > OTC Medicine/Cough & Cold > OTC - Pain Relievers (Kids; Brand); Cough & Cold (Kids; Brand),HBA/OTC,2842
# Tru Optik > V12Data > Income > Income Range: K-$100K-$149.9K,Income,74492
# Tru Optik > V12Data > Financial > Credit Card Holder,Financial/Insurance Attributes & Behaviors,42083
# Tru Optik > V12Data > Health & Beauty > Women's Health & Beauty Aids,HBA/OTC,2113
# Tru Optik > V12Data > Health & Beauty > Men's Health & Beauty Aids,HBA/OTC,2213
# Tru Optik > Media Source Solutions > Health & Wellness > Exercise,Health & Fitness/Wellness,5719
# Tru Optik > V12Data > Pet > Pet Food & Treats,Pet,1918
# Tru Optik > Cross Pixel > Financial > Auto/Home/Life Insurance,Auto,2138
# Tru Optik > Cross Pixel > Financial > Health Insurance,Health & Fitness/Wellness,3053
# Tru Optik > Cross Pixel > Real Estate > Home Buyers,Home Imp/Décor/Home & Garden/Home&Fam/DIY,158
# Tru Optik > Cross Pixel > Travel > US & Canada,Travel,465
# Tru Optik > Cross Pixel > Travel > Caribbean; Central & South America,Travel,2
# Tru Optik > Cross Pixel > Travel > EU; Africa; Asia-Pacific,Travel,12
# Tru Optik > Cross Pixel > Food & Dining > Mid-Scale Restaurants,Food & Dining,4924
# Tru Optik > MillwardBrown > Travel > Globe Trotters,Travel,17784
# Tru Optik > MillwardBrown > Travel > Travel Seekers,Travel,423
# Tru Optik > Alliant > Auto > Auto - In Market for Used Vehicle,Auto,71423
# Tru Optik > Alliant > Purchase Affinity > Health Wellness and Fitness,Health & Fitness/Wellness,4306
# Tru Optik > Alliant > Purchase Affinity > Home Decor,Home Imp/Décor/Home & Garden/Home&Fam/DIY,10233
# Tru Optik > Alliant > Purchase Affinity > Sports Enthusiasts,Sporting & Healthy Living + Sporting Goods/Outdoor,9250
# Tru Optik > Alliant > Purchase Affinity > Men's Interests,Demo,132
# Tru Optik > Alliant > Purchase Affinity > Moms Who Shop Like Crazy,Retail,137332
# Tru Optik > Alliant > Purchase Affinity > Affluent Consumers,Financial/Insurance Attributes & Behaviors,12509
# Tru Optik > Alliant > Purchase Affinity > Fitness and Exercise,Health & Fitness/Wellness,18
# Tru Optik > Alliant > Auto > Auto - In Market for Parts & Service,Auto,1758
# Tru Optik > Alliant > Demographics > Household Income 50k+,Income,1705
# Tru Optik > Alliant > Demographics > Household Income 100k+,Income,18348
# Tru Optik > Alliant > Demographics > Household Income 150k+,Income,17485
# Tru Optik > Alliant > Demographics > Household Presence of Children Age 0-4,Demo - Age,10930
# Tru Optik > Alliant > Demographics > Household Presence of Children Age 4-8,Demo - Age,5484
# Tru Optik > Alliant > Demographics > Household Presence of Children Age 8-13,Demo - Age,8916
# Tru Optik > Alliant > Demographics > Household Presence of Children Age 13-18,Demo - Age,4003
# Tru Optik > Alliant > Propensity > Cruise Travel - Propensity,Travel,2587
# Tru Optik > Alliant > Propensity > Online Travel Planners - Propensity,Travel,896
# Tru Optik > Alliant > Propensity > NASCAR Fans - Propensity,Sports (Fans/Programming),984
# Tru Optik > Alliant > Home Renovation > Home Renovators,Home Imp/Décor/Home & Garden/Home&Fam/DIY,2543
# Tru Optik > Alliant > Demographics > 18-25,Demo - Age,2016
# Tru Optik > Netwise > Demographics > Age 50+,Demo - Age,662
# Tru Optik > NinthDecimal > Do It Yourself DIY > Home Improvement/Hardware Shoppers,Home Imp/Décor/Home & Garden/Home&Fam/DIY,2412
# Tru Optik > NinthDecimal > Food & Dining > Casual Dining,Food & Dining,1726
# Tru Optik > NinthDecimal > Food & Dining > Fast Food Enthusiasts,Food & Dining,1631
# Tru Optik > NinthDecimal > Retail > New/Expectant Mom Shoppers,Retail,784
# Tru Optik > NinthDecimal > Sports and Healthy Living > Outdoor Enthusiasts,Sporting & Healthy Living + Sporting Goods/Outdoor,14405
# Tru Optik > NinthDecimal > Sports and Healthy Living > Health & Fitness Enthusiasts,Health & Fitness/Wellness,4958
# Tru Optik > NinthDecimal > Technology > Tech Enthusiasts,COMPUTERS/TECHNOLOGY,129
# Tru Optik > NinthDecimal > Auto > In Market Auto Intenders,Auto,52845
# Tru Optik > NinthDecimal > Lifestyle > College Students,Demo,6064
# Tru Optik > NinthDecimal > Retail > Jewelry Store Shoppers,Retail,4502
# Tru Optik > NinthDecimal > Retail > Grocery Store Shoppers,Retail,20710
# Tru Optik > Webbula > Demographics > Financial Attributes > New Credit Line Amount > $501 - $1;000,Financial/Insurance Attributes & Behaviors,316
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > Retail/Gas Card,Financial/Insurance Attributes & Behaviors,4342
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $100;000 - $124;999,Financial/Insurance Attributes & Behaviors,36068
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $125;000 - $149;999,Financial/Insurance Attributes & Behaviors,20466
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $150;000 - $174;999,Financial/Insurance Attributes & Behaviors,23331
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $175;000 - $199;999,Financial/Insurance Attributes & Behaviors,22474
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $200;000 - $224;999,Financial/Insurance Attributes & Behaviors,19302
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $225;000 - $249;999,Financial/Insurance Attributes & Behaviors,13283
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $250;000 - $274;999,Financial/Insurance Attributes & Behaviors,12347
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $275;000 - $299;999,Financial/Insurance Attributes & Behaviors,8997
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $300;000 - $349;999,Financial/Insurance Attributes & Behaviors,14308
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $350;000 - $399;999,Financial/Insurance Attributes & Behaviors,13902
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $400;000 - $449;999,Financial/Insurance Attributes & Behaviors,11198
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $450;000 - $499;999,Financial/Insurance Attributes & Behaviors,8350
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $500;000 - $749;999,Financial/Insurance Attributes & Behaviors,18060
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $750;000 - $999;999,Financial/Insurance Attributes & Behaviors,4342
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Ownership > Owner > Highly Likely,Financial/Insurance Attributes & Behaviors,35211
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $25;000 - $49;999,Financial/Insurance Attributes & Behaviors,6169
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $50;000 - $74;999,Financial/Insurance Attributes & Behaviors,25018
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $75;000 - $99;999,Financial/Insurance Attributes & Behaviors,21950
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Dealer/Retailer/Storekeeper,B2B,38
# Tru Optik > Webbula > Demographics > Financial Attributes > Credit Card Holders > Premium Visa,Financial/Insurance Attributes & Behaviors,2742
# Tru Optik > Webbula > Demographics > Housing Attributes > Home Market Value > $1;000 - $24;999,Financial/Insurance Attributes & Behaviors,4366
# Tru Optik > Webbula > Demographics > Financial Attributes > New Credit Line Amount > $1;001 +,Financial/Insurance Attributes & Behaviors,3515
# Tru Optik > Webbula > Demographics > Financial Attributes > Loans > Refinance,Financial/Insurance Attributes & Behaviors,4461
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > El Salvador,Demo - Hispanic,37
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Puerto Rico,Demo - Hispanic,5925
# Tru Optik > Webbula > Demographics > Education > Vocational/Technical School,Demo,7917
# Tru Optik > Webbula > Demographics > Ethnicity > Caribbean African American,Demo - African,7
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Guatemala,Demo - Hispanic,9
# Tru Optik > Webbula > Demographics > Military Status > Veteran in Household,Demo,30437
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Builder,B2B,30
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Partner,B2B,139
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Colombia,Demo - Hispanic,14
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Honduras,Demo - Hispanic,12
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Paraguay,Demo - Hispanic,3
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Bolivia,Demo - Hispanic,1
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Ecuador,Demo - Hispanic,20
# Tru Optik > Webbula > Demographics > Employment > Business Owner > Owner,B2B,1579
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Brazil,Demo - Hispanic,41
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Mexico,Demo - Hispanic,5962
# Tru Optik > Webbula > Demographics > Employment > Occupation > Military,Demo,512
# Tru Optik > Webbula > Demographics > Employment > Status > Job Seekers,Education & Career,1789
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Cuba,Demo - Hispanic,278
# Tru Optik > Webbula > Demographics > Hispanic Country of Origin > Peru,Demo - Hispanic,1
# Tru Optik > Webbula > Demographics > Education > Undergraduate Degree,Education & Career,47612
# Tru Optik > Webbula > Demographics > Education > High School Diploma,Education & Career,114865
# Tru Optik > Webbula > Demographics > Employment > Status > Student,Education & Career,3366
# Tru Optik > Webbula > Demographics > Ethnicity > African American,Demo - African,12683
# Tru Optik > Webbula > Demographics > Education > Graduate Degree,Education & Career,10211
# Tru Optik > Webbula > Demographics > Ethnic Group > Hispanic,Demo - Hispanic,7016
# Tru Optik > Webbula > Demographics > Ethnicity > Hispanic,Demo - Hispanic,3197
# Tru Optik > Webbula > Demographics > Age > 18-24,Demo - Age,334
# Tru Optik > Webbula > Demographics > Financial Attributes > Mortgage Holder > Loan to Value > 1 - 100 LTV,Financial/Insurance Attributes & Behaviors,886
# Tru Optik > Webbula > Demographics > Financial Attributes > Mortgage Holder > Prospector Home Value > $50;000 - $74;999,Financial/Insurance Attributes & Behaviors,38
# Tru Optik > Webbula > Demographics > Financial Attributes > Mortgage Holder > Prospector Home Value > $75;000 - $99;999,Financial/Insurance Attributes & Behaviors,741
# Tru Optik > Webbula > Demographics > Financial Attributes > Mortgage Holder > Purchase Price > $150;000 - $199;999,Financial/Insurance Attributes & Behaviors,22
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Hummer,Auto,110
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Hyundai,Auto,8265
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Infiniti,Auto,750
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Isuzu,Auto,30
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Jaguar,Auto,100
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Jeep,Auto,12789
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Kia,Auto,4712
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Land-Rover,Auto,108
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Lexus,Auto,4642
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Lincoln,Auto,465
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Low End Imports,Auto,3104
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Maserati,Auto,1
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Mazda,Auto,2222
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Mercedes Benz,Auto,2227
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Mercury,Auto,110
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Mini,Auto,25
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Mitsubishi,Auto,602
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Nissan,Auto,33060
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Oldsmobile,Auto,53
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Plymouth,Auto,111
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Pontiac,Auto,629
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Porsche,Auto,1
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > RAM,Auto,1326
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Saab,Auto,12
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Saturn,Auto,341
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Scion,Auto,113
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Subaru,Auto,23851
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Suzuki,Auto,80
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Toyota,Auto,49612
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Volkswagen,Auto,9184
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Manufacturer > Volvo,Auto,48
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Number of Vehicles > 1,Auto,2809
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Number of Vehicles > 2,Auto,2472
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Number of Vehicles > 3,Auto,1476
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Number of Vehicles > 4 +,Auto,2282
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Purchase Type > New,Auto,4338
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Purchase Type > Used,Auto,10117
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > transaction > Change of Ownership,Auto,37
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > transaction > New Registration,Auto,32
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > transaction > Other,Auto,388
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1989 or earlier,Auto,44
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1990,Auto,4
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1991,Auto,10
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1993,Auto,19
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1994,Auto,4
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1995,Auto,118
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1996,Auto,6
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1997,Auto,165
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1998,Auto,4
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 1999,Auto,6
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2000,Auto,90
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2001,Auto,175
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2002,Auto,381
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2003,Auto,796
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2004,Auto,386
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2005,Auto,300
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2006,Auto,314
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2007,Auto,1613
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2008,Auto,1038
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2009,Auto,613
# Tru Optik > Webbula > Historical Buyer or Shopper of > Autos; Car > Year Built > 2010,Auto,1771
# Tru Optik > Webbula > B2B > Industry > Retail Trade > Furniture and Home Furnishings Stores,Home Imp/Décor/Home & Garden/Home&Fam/DIY,799
# Tru Optik > Webbula > B2B > Title|Career|Role > Administration Executive,B2B,10
# Tru Optik > Webbula > B2B > Title|Career|Role > Chief Administrative Officer,B2B,2048
# Tru Optik > Webbula > B2B > Title|Career|Role > Chief Executive Officer,B2B,115941
# Tru Optik > Webbula > B2B > Title|Career|Role > Chief Financial Officer,B2B,23880
# Tru Optik > Webbula > B2B > Title|Career|Role > Chief Marketing Officer,B2B,12298
# Tru Optik > Webbula > B2B > Title|Career|Role > Chief Operating Officer,B2B,17133
# Tru Optik > Webbula > B2B > Title|Career|Role > Director,B2B,39
# Tru Optik > Webbula > B2B > Title|Career|Role > Engineering/Technical,B2B,9
# Tru Optik > Webbula > B2B > Title|Career|Role > Executive Director,B2B,112
# Tru Optik > Webbula > B2B > Title|Career|Role > Executive Officer,B2B,41
# Tru Optik > Webbula > B2B > Title|Career|Role > Executive Vice President,B2B,1
# Tru Optik > Webbula > B2B > Title|Career|Role > Finance Executive,B2B,69
# Tru Optik > Webbula > B2B > Title|Career|Role > General Manager,B2B,4
# Tru Optik > Webbula > B2B > Title|Career|Role > Human Resources Executive,B2B,127
# Tru Optik > Webbula > B2B > Title|Career|Role > IT Executive,B2B,5
# Tru Optik > Webbula > B2B > Title|Career|Role > Manager,B2B,3124
# Tru Optik > Webbula > B2B > Title|Career|Role > Manufacturing Executive,B2B,18
# Tru Optik > Webbula > B2B > Title|Career|Role > Marketing Executive,B2B,1
# Tru Optik > Webbula > B2B > Title|Career|Role > Office Manager,B2B,56
# Tru Optik > Webbula > B2B > Title|Career|Role > Operations Executive,B2B,3
# Tru Optik > Webbula > B2B > Title|Career|Role > President,B2B,1430
# Tru Optik > Webbula > B2B > Title|Career|Role > Sales Executive,B2B,188
# Tru Optik > Webbula > B2B > Title|Career|Role > Site Manager,B2B,255
# Tru Optik > Webbula > B2B > Title|Career|Role > Telecommunications Executive,B2B,4
# Tru Optik > Webbula > B2B > Title|Career|Role > Vice President,B2B,104
# Tru Optik > Webbula > B2B Premium > Company > Manufacturing > Consumer Products > Auto|Car|Vehicles & Vehicle Components,B2B,1
# Tru Optik > Webbula > B2B Premium > Company > Manufacturing > Defense & Law Enforcement > Military Equipment,B2B,1
# Tru Optik > Webbula > B2B Premium > Company > Manufacturing > Engineering Equipment > Automation Systems,B2B,5
# Tru Optik > Webbula > B2B Premium > Company > Manufacturing > Industry Served > Automotive Industry,B2B,52
# Tru Optik > Webbula > B2B Premium > Employment > Unemployed,B2B,6903
# Tru Optik > Webbula > B2B Premium > Functional Area > C-Suite,B2B,2419
# Tru Optik > Webbula > B2B Premium > Functional Area > Finance,B2B,112
# Tru Optik > Webbula > B2B Premium > Functional Area > Finance > Accounting,B2B,12
# Tru Optik > Webbula > B2B Premium > Functional Area > Finance > Banking,B2B,70
# Tru Optik > Webbula > B2B Premium > Functional Area > Finance > Investment Banking,B2B,22
# Tru Optik > Webbula > B2B Premium > Functional Area > Finance > Wealth Management,B2B,520
# Tru Optik > Webbula > B2B Premium > Functional Area > Government > Elected Officials,B2B,317
# Tru Optik > Webbula > B2B Premium > Industry|Occupation|Career|Job > Finance,B2B,572
# Tru Optik > Webbula > B2B Premium > Industry|Occupation|Career|Job > Government,B2B,8896
# Tru Optik > Webbula > B2B Premium > Occupation > Active Military,B2B,119
# Tru Optik > Webbula > B2B Premium > Occupation > Active Military > Air Force,B2B,3
# Tru Optik > Webbula > B2B Premium > Occupation > Active Military > Army,B2B,18
# Tru Optik > Webbula > B2B Premium > Occupation > Active Military > Marines,B2B,10
# Tru Optik > Webbula > B2B Premium > Occupation > Active Military > Navy,B2B,1
# Tru Optik > Webbula > B2B Premium > Professional Groups > Medical Directors,B2B,191
# Tru Optik > Webbula > B2B Premium > Roles > Business Owner,B2B,13145
# Tru Optik > Webbula > B2B Premium > Roles > Seniority > Executives,B2B,2046
# Tru Optik > Alliant > Propensity > Home Depot Buyer Propensity,Home Imp/Décor/Home & Garden/Home&Fam/DIY,5045
# Tru Optik > Alliant > Propensity > Petco Buyer Propensity,Pet,937
# Tru Optik > Lotame > Advanced Demographics > Moms,Demo,217177
# Tru Optik > Lotame > vCE Optimized > Lotame_vCE Optimized_Age: 18-24_M,Demo - Age x Gender,182
# Tru Optik > Infogroup > Seniority > Director,B2B,628
# Tru Optik > Infogroup > Seniority > C-Level,B2B,189110
# Tru Optik > Infogroup > Decision Makers > Small Business Decision Makers,B2B,140877
# Tru Optik > Infogroup > Functional Area > Medical and Health Services > Physicians,B2B,164
# Tru Optik > Infogroup > Seniority > Board Level,20389
# Tru Optik > Infogroup > Industry > Banking and Finance,Financial/Insurance Attributes & Behaviors,12326
# Tru Optik > Infogroup > Decision Makers > Medical & Health Services -- Co-op Sourced Decision Makers,B2B,236
# Tru Optik > Infogroup > Seniority > Vice President,B2B,22945
# Tru Optik > Infogroup > Functional Area > Medical and Health Services,B2B,7990
# ...
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Subcompact Car Rank 3,Auto,12110
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Fullsize Car Rank 1,Auto,19608
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact SUV Rank 2,Auto,21351
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 1/2 ton Fullsize Van Rank 4,Auto,13735
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Fullsize Car Rank 4,Auto,21212
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact SUV Rank 4,Auto,17746
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Pickup Rank 3,Auto,8731
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Sports Car Rank 1,Auto,11958
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Compact Car Rank 3,Auto,7768
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize SUV Rank 4,Auto,7816
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 1/2 ton Fullsize Van Rank 2,Auto,10872
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Van Rank 3,Auto,7973
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact SUV Rank 1,Auto,10269
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize CUV Rank 2,Auto,14446
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Fullsize Prestige Car Rank 4,Auto,8296
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize SUV Rank 2,Auto,8170
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Compact CUV Rank 1,Auto,8237
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize Car Rank 3,Auto,8641
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Sports Car Rank 1,Auto,4646
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Midsize Car Rank 2,Auto,12117
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Subcompact Car Rank 2,Auto,13260
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize SUV Rank 1,Auto,19872
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Sports Car Rank 3,Auto,14621
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Exotic Car Rank 1,Auto,7772
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Car Rank 4,Auto,17569
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Sports Car Rank 2,Auto,6652
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize SUV Rank 2,Auto,17349
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize CUV Rank 1,Auto,17513
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Fullsize Prestige Car Rank 3,Auto,5790
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Subcompact Car Rank 2,Auto,28499
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 1/2 ton Fullsize Pickup Rank 2,Auto,8269
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Fullsize SUV Rank 2,Auto,12883
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Subcompact Car Rank 4,Auto,20997
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact Van Rank 2,Auto,20915
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 3/4 or 1 ton Fullsize Pickup Rank 1,Auto,4385
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Sports Car Rank 4,Auto,6674
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact SUV Rank 3,Auto,13591
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Van Rank 2,Auto,6564
# Tru Optik > Polk IHSM > Purchase Predictor > Luxury Exotic Car Rank 3,Auto,7914
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Sports Car Rank 4,Auto,9212
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact Van Rank 4,Auto,20926
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact CUV Rank 3,Auto,23463
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 3/4 or 1 ton Fullsize Van Rank 4,Auto,9314
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize SUV Rank 4,Auto,21557
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Compact Car Rank 3,Auto,15875
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Sports Car Rank 3,Auto,9829
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Subcompact Car Rank 3,Auto,19656
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize Car Rank 2,Auto,22210
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Fullsize SUV Rank 1,Auto,10264
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury 3/4 or 1 ton Fullsize Van Rank 2,Auto,10699
# Tru Optik > Polk IHSM > Purchase Predictor > Nonluxury Midsize SUV Rank 3,Auto,23617
# Tru Optik > Polk IHSM > Garage Predictor > Acura,Auto,4909
# Tru Optik > Polk IHSM > Garage Predictor > Audi,Auto,167
# Tru Optik > Polk IHSM > Garage Predictor > BMW,Auto,467
# Tru Optik > Polk IHSM > Garage Predictor > Buick,Auto,1211
# Tru Optik > Polk IHSM > Garage Predictor > Cadillac,Auto,450
# Tru Optik > Polk IHSM > Garage Predictor > Chevrolet division car,Auto,14674
# Tru Optik > Polk IHSM > Garage Predictor > Chevrolet division truck,Auto,19985
# Tru Optik > Polk IHSM > Garage Predictor > Chrysler division vehicle,Auto,4059
# Tru Optik > Polk IHSM > Garage Predictor > Dodge division car,Auto,2817
# Tru Optik > Polk IHSM > Garage Predictor > Dodge division truck,Auto,7729
# Tru Optik > Polk IHSM > Garage Predictor > Fiat Chrysler Automobiles corporation vehicle,Auto,39167
# Tru Optik > Polk IHSM > Garage Predictor > Ford corporation vehicle,Auto,60013
# Tru Optik > Polk IHSM > Garage Predictor > Ford division car,Auto,3918
# Tru Optik > Polk IHSM > Garage Predictor > Ford division truck,Auto,10166
# Tru Optik > Polk IHSM > Garage Predictor > GM corporation vehicle,Auto,47400
# Tru Optik > Polk IHSM > Garage Predictor > GMC division vehicle,Auto,182691
# Tru Optik > Polk IHSM > Garage Predictor > Honda,Auto,23180
# Tru Optik > Polk IHSM > Garage Predictor > Hummer,Auto,10
# Tru Optik > Polk IHSM > Garage Predictor > Hyundai,Auto,1672
# Tru Optik > Polk IHSM > Garage Predictor > Infiniti,Auto,157
# Tru Optik > Polk IHSM > Garage Predictor > Isuzu,Auto,6
# Tru Optik > Polk IHSM > Garage Predictor > Jaguar,Auto,1034
# Tru Optik > Polk IHSM > Garage Predictor > Jeep/Eagle,Auto,2963
# Tru Optik > Polk IHSM > Garage Predictor > Kia,Auto,4798
# Tru Optik > Polk IHSM > Garage Predictor > Land Rover,Auto,81
# Tru Optik > Polk IHSM > Garage Predictor > Lexus,Auto,346
# Tru Optik > Polk IHSM > Garage Predictor > Lincoln,Auto,188
# Tru Optik > Polk IHSM > Garage Predictor > Mazda,Auto,729
# Tru Optik > Polk IHSM > Garage Predictor > Mercedes,Auto,458
# Tru Optik > Polk IHSM > Garage Predictor > Mercury,Auto,128
# Tru Optik > Polk IHSM > Garage Predictor > Mini,Auto,40
# Tru Optik > Polk IHSM > Garage Predictor > Mitsubishi,Auto,88
# Tru Optik > Polk IHSM > Garage Predictor > Nissan,Auto,86379
# Tru Optik > Polk IHSM > Garage Predictor > Oldsmobile,Auto,46
# Tru Optik > Polk IHSM > Garage Predictor > Plymouth,Auto,25
# Tru Optik > Polk IHSM > Garage Predictor > Pontiac,Auto,212
# Tru Optik > Polk IHSM > Garage Predictor > Porsche,Auto,53
# Tru Optik > Polk IHSM > Garage Predictor > Saab,Auto,57
# Tru Optik > Polk IHSM > Garage Predictor > Saturn,Auto,113
# Tru Optik > Polk IHSM > Garage Predictor > Subaru,Auto,40644
# Tru Optik > Polk IHSM > Garage Predictor > Suzuki,Auto,46
# Tru Optik > Polk IHSM > Garage Predictor > Toyota,Auto,80257
# Tru Optik > Polk IHSM > Garage Predictor > Volkswagen,Auto,17601
# Tru Optik > Polk IHSM > Garage Predictor > Volvo,Auto,807
# Tru Optik > Polk IHSM > Garage Predictor > Convertible,Auto,292
# Tru Optik > Polk IHSM > Garage Predictor > Coupe,Auto,216
# Tru Optik > Polk IHSM > Garage Predictor > Luxury compact car,Auto,6081
# Tru Optik > Polk IHSM > Garage Predictor > Luxury compact CUV,Auto,129
# Tru Optik > Polk IHSM > Garage Predictor > Luxury exotic car,Auto,1
# Tru Optik > Polk IHSM > Garage Predictor > Luxury full-size car,Auto,4271
# Tru Optik > Polk IHSM > Garage Predictor > Luxury full-size SUV,Auto,1018
# Tru Optik > Polk IHSM > Garage Predictor > Luxury mid-size car,Auto,5535
# Tru Optik > Polk IHSM > Garage Predictor > Luxury mid-size CUV,Auto,3547
# Tru Optik > Polk IHSM > Garage Predictor > Luxury mid-size SUV,Auto,71
# Tru Optik > Polk IHSM > Garage Predictor > Luxury prestige full-size car,Auto,2
# Tru Optik > Polk IHSM > Garage Predictor > Luxury sporty car,Auto,1617
# Tru Optik > Polk IHSM > Garage Predictor > Luxury subcompact car,Auto,150
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury compact car,Auto,15131
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury compact CUV,Auto,3295
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury compact pickup,Auto,98
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury compact SUV,Auto,773
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury compact van,Auto,73
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury full-size 1/2 ton pickup,Auto,3176
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury full-size 3/4 -1 ton van,Auto,16
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury full-size 3/4 or 1 ton pickup,Auto,1408
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury full-size car,Auto,3328
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury full-size half ton van,Auto,58
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury full-size SUV,Auto,1270
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury mid-size car,Auto,9163
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury mid-size CUV,Auto,1597
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury mid-size pickup,Auto,2440
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury mid-size SUV,Auto,2631
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury mid-size van,Auto,11733971
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury sport mid-size car,Auto,417
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury sporty car,Auto,215
# Tru Optik > Polk IHSM > Garage Predictor > Non-luxury subcompact car,Auto,787
# Tru Optik > Polk IHSM > Garage Predictor > Sedan,Auto,33571
# Tru Optik > comScore > Demographics > Males: 18-24,Demo - Age x Gender,745
# Tru Optik > comScore > Demographics > Females: 18-24,Demo - Age x Gender,384
# Tru Optik > comScore > Demographics > Persons: 18-24,Demo - Age,1852
# Tru Optik > MillwardBrown > Business and Financial > Entrepeneurs and Innovators,Financial/Insurance Attributes & Behaviors,3
# Tru Optik > MillwardBrown > Business and Financial > Financial Market Followers,Financial/Insurance Attributes & Behaviors,3
# Tru Optik > MillwardBrown > Business and Financial > Investors,Financial/Insurance Attributes & Behaviors,1
# Tru Optik > Alliant > Purchase Affinity > Cooking/Food Enthusiasts,Food & Dining,44
# Tru Optik > Alliant > Purchase Affinity > Cosmetics/Beauty,Fashion/Style; Apparel; Accessories,31
# Tru Optik > Alliant > Purchase Affinity > Lawn & Garden Enthusiasts,Home Imp/Décor/Home & Garden/Home&Fam/DIY,2
# Tru Optik > Netwise > Company Services > Company Uses Data Center Technologies,B2B,2
# Tru Optik > Netwise > Company Services > Company Uses Marketing/Sales Management Technologies,B2B,89
# Tru Optik > Dataline > Buyers > Book Buyer,Arts & Culture,39
# Tru Optik > Dataline > Buyers > Computer & Technology Buyer,COMPUTERS/TECHNOLOGY,17
# Tru Optik > Dataline > Purchasing Interest > Technology Products Purchase Interest,COMPUTERS/TECHNOLOGY,57
# Tru Optik > Webbula > Historical Buyer or Shopper of > Electronics > Portable Music Player,COMPUTERS/TECHNOLOGY,19
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Business,Arts & Culture,86
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Inspirational,Arts & Culture,1
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Magazines,Arts & Culture,1
# Tru Optik > Webbula > Passionate About > Arts & Entertainment > Reading > Science Fiction,Arts & Culture,2
# Tru Optik > Webbula > Passionate About > Business & Finance > Money Seekers,Financial/Insurance Attributes & Behaviors,1
# Tru Optik > Webbula > Passionate About > Hobbies > Avid Music Listener,Arts & Culture,18
# Tru Optik > Webbula > Passionate About > Hobbies > Collecting > Music,Arts & Culture,2
# Tru Optik > Webbula > Passionate About > Hobbies > Movies & Music,Arts & Culture,34
# Tru Optik > Webbula > Shopper Currently Seeking > Collectibles > Sports Memorabelia,1
# Tru Optik > Webbula > B2B > Industry > Arts; Entertainment; and Recreation,B2B,2
# Tru Optik > Webbula > B2B Premium > Company > Technologies Used > Data Center > Operating Systems & Computing Languages,B2B,5
# Tru Optik > Webbula > B2B Premium > Company > Technologies Used > Marketing Performance Management,B2B,6
# Tru Optik > Webbula > B2B Premium > Company > Technologies Used > Web Oriented Architecture,B2B,12
# Tru Optik > Webbula > B2B Premium > Company > Technologies Used > Web Oriented Architecture > Online Video,B2B,9
# Tru Optik > Webbula > B2B Premium > Company > Technologies Used > Web Oriented Architecture > Virtualization Data Center,B2B,3
# Tru Optik > Webbula > B2B Premium > Company > Technologies Used > Web Oriented Architecture > Web Content Management,B2B,1
# Tru Optik > Webbula > B2B Premium > Roles > Management,B2B,8
# Tru Optik > Infogroup > Industry > Business Services > Marketing; Advertising and Sales,B2B,72
# Tru Optik > Infogroup > Company > Specialty > Small Businesses,B2B,51
# Tru Optik > Infogroup > Technology Onsite > Hardware > Apple > Apple Device -- Co-op Sourced,B2B,12
# Tru Optik > Infogroup > Technology Onsite > Software > Antivirus -- Co-op Sourced,B2B,112
# Tru Optik > Kantar - Shopcom > CPG > Sports Drinks,Sporting & Healthy Living + Sporting Goods/Outdoor,94
# Tru Optik > Kantar - Shopcom > Apparel > Mens > Suits - Sport Coats - Tailored Items,Fashion/Style; Apparel; Accessories,5
# Tru Optik > Lotame > Advanced Demographics > Home Type - Apartment,Demo,38
# Tru Optik > Lotame > Advanced Demographics > Home Type - Condo,Demo,49
# Tru Optik > Lotame > Business > Business - IT Professionals,B2B,14
# Tru Optik > Lotame > Business > Business - Small Business Professionals,B2B,38
# Tru Optik > Lotame > Business > Career & Employment,B2B,85
# Tru Optik > Lotame > Entertainment > Pop Music,Entertainment & Media,9
# Tru Optik > Lotame > Personal Finance > Estate Planning,Financial/Insurance Attributes & Behaviors,5
# Tru Optik > Lotame > Style; Fashion; & Clothing > Online Shoppers Luxury,Fashion/Style; Apparel; Accessories,2
# Tru Optik > Lotame > Style; Fashion; & Clothing > Shoppers Mens Clothing Luxury,Fashion/Style; Apparel; Accessories,11
# Tru Optik > Lotame > Style; Fashion; & Clothing > Shoppers Womens Clothing Luxury,Fashion/Style; Apparel; Accessories,2
# Tru Optik > Lotame > Style; Fashion; & Clothing > Shoppers Cosmetics Luxury,Fashion/Style; Apparel; Accessories,24
# Tru Optik > Lotame > Technology > Computers & Technology,COMPUTERS/TECHNOLOGY,117
# Tru Optik > Lotame > Technology > Electronics & Gadgets,COMPUTERS/TECHNOLOGY,37
# Tru Optik > Lotame > Technology > Home Audio & Video,Entertainment & Media,35
# Tru Optik > Lotame > Technology > Mobile Phones,COMPUTERS/TECHNOLOGY,64
# Tru Optik > Lotame > Technology > Web Design & Digital Art,COMPUTERS/TECHNOLOGY,115
# Key: Auto
# Value: 16143614
# Key: HBA/OTC
# Value: 30219
# Key: Income
# Value: 1222638
# Key: Financial/Insurance Attributes & Behaviors
# Value: 1068107
# Key: Health & Fitness/Wellness
# Value: 95494
# Key: Pet
# Value: 18554
# Key: Home Imp/Décor/Home & Garden/Home&Fam/DIY
# Value: 385871
# Key: Travel
# Value: 86285
# Key: Food & Dining
# Value: 70063
# Key: Appliances
# Value: 41984
# Key: Demo - African
# Value: 66275
# Key: Demo - Hispanic
# Value: 44063
# Key: Fashion/Style; Apparel; Accessories
# Value: 55982
# Key: Demo
# Value: 676742
# Key: Entertainment & Media
# Value: 97353
# Key: TOYS & GAMES
# Value: 3764
# Key: News & Info
# Value: 239274
# Key: Sports (Fans/Programming)
# Value: 963499
# Key: Sporting & Health & Fitness/Wellnessy Living + Sporting Goods/Outdoor
# Value: 401049
# Key: Retail
# Value: 168837
# Key: Demo - Age
# Value: 267433
# Key: COMPUTERS/TECHNOLOGY
# Value: 2583
# Key: Furniture
# Value: 118550
# Key: Collectables
# Value: 1536
# Key: B2B
# Value: 699849
# Key: Education & Career
# Value: 375998
# Key: Arts & Culture
# Value: 13343
# Key: Politics
# Value: 81390
# Key: Demo - Age x Gender
# Value: 1516
# Key:
# Value: 20390
# Key: Demo - Gender
# Value: 1467
# Key: Real Estate/Movers
# Value: 1118

# %%
#SIDE PROJECT: CREATE A DATABASE OF VALUES THAT HAVE CORRECT LABELS
#RUN ONLY ONCE: THIS WILL OVERWRITE THE CURRENT DATABASE
folder_path = '/Users/default/Documents/PythonMisc/Videology Reports - Completed'
folder_contents = os.listdir(folder_path)

db_path = '/Users/default/Documents/PythonMisc/VideologyDatabase.xlsx'
db_file = load_workbook(db_path)
db_ws = db_file.active
db_contents = {}
pattern = '^[Ee]'

print(len(db_contents))
for attribute, category in [[i.value for i in x] for x in db_ws.iter_rows(max_col=2)]:
    db_contents[attribute] = category

for file in folder_contents:
    if re.match(pattern, file):
        wb = load_workbook(folder_path + '/' + file)
        ws = wb.active

        #only want the first 2 columns (attribute and category)
        for attribute, category in [[i.value for i in x] for x in ws.iter_rows(max_col=2)]:
            if attribute is None:
                attribute = 'TEST'
                category = 'TEST'
            if '>' == attribute[-1]:
                attribute = attribute[:-2]
            try:
                category = replacements(category)
            except:
                print('no bueno')
            db_contents[attribute] = category

print(len(db_contents))

#Now, we write the completed dictionary to the database file again
for i, (key, value) in enumerate(db_contents.items()):
    db_ws.cell(row=i+1, column = 1).value = key
    db_ws.cell(row=i+1, column = 2).value = value
    
db_file.save(db_path)
# Out:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-82dab72968d7> in <module>()
#      15
#      16 for file in folder_contents:
# ---> 17     if re.match(pattern, file):
#      18         wb = load_workbook(folder_path + '/' + file)
#      19         ws = wb.active
#
# NameError: name 'pattern' is not defined

# %%
fte = '/Users/default/Downloads/Final-TruOptik - Monthly Usage - July 2018.xlsx'
wb = load_workbook(fte)
ws = wb.active


cd = {}
for line in ws.iter_rows(min_col=2,max_col = 3):
    row = [x.value for x in line]
    if row[0] not in cd.keys():
        cd[row[0]] = row[1]
    elif row[0] in cd.keys():
        cd[row[0]] += row[1]
for i,(k,v) in enumerate(cd.items(),start=1):
    ws.cell(row=i, column = 6).value = k
    ws.cell(row=i, column = 7).value = v
    
wb.save(fte)

# %%
#Load the model and
